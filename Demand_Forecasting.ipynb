# %% [markdown]
# ### How to Not Mislead Your Forecasting Model

# %% [markdown]
# According to the Oxford Dictionary "forecasting" means to say what you think will happen in the future based on information that you have now. Saying what will happen is a big challenge itself, but the second expression in the definition gives us a better understanding about why time series forecasting differs from other machine learning problems. For example in an image classification problem we can collect lots of images and train a  model to successfully  classify the upcoming images. If there is no difference in the format of the images, the data we predict is not fundamentally different from the training data. However, when it comes to time series forecasting, things may get a bit complicated. In this article we are going to try to solve a time series forecasting problem, investigate and solve the potential problems we may face in a made up (but probable) scenario.
#
# Let's say we are in 2018 and we are trying to forecast the hourly energy consumption in Spain. We'd love to have historical hourly consumption values as our both target and source of different features we can derive. Maybe we don't know much about recurrent neural networks like LSTM, GRU because we don't care about applying state of the art solutions in our business or just because we want to help a person to simlify his blog post for underpinning his  idea. Hence we use lightgbm and create trend and seasonality related features. And we'd like to have different features related with the target, it could be any signal and for demand forecasting, weather features are promising candidates. At first we'd simply use the weather features to check if there was an improvement and if so we'd start thinking go back to the definition and ask "Do we use the only information we have now?".
#
# At this stage we are going to extract a couple of very simple lagged features of the target(consumption) values and build a baseline lightgbm model to forecast the day-ahead electricity consumption in Spain. Then, to improve the baseline we will use 2 weather features from an external data source and benchmark the results of the models with and without weather features. Afterwards the fun part begins.

# %% [markdown]
# ### Disclaimer

# %% [markdown]
# It must not be considered as a full demand forecasting project. This article is written only with the aim of giving a regularization idea to the readers while using the weather forecasts of 3rd party data source. Therefore the code and feature engineering are kept as simple as possible.

# %% [markdown]
# ### First Benchmark

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",500)
import lightgbm as lgb
from datetime import timedelta
import matplotlib.pyplot as plt
import numpy as np
TARGET = "total load actual"
Seed = 5

# %% [markdown]
# Let's read and merge the hourly consumption and weather dataframes.

# %%
demand = pd.read_parquet("spain_demand.parquet")
weather = pd.read_parquet("spain_weather.parquet")

# %%
display(demand)
# Out:
#                      time  total load actual
# 0     2015-01-01 00:00:00            25385.0
# 1     2015-01-01 01:00:00            24382.0
# 2     2015-01-01 02:00:00            22734.0
# 3     2015-01-01 03:00:00            21286.0
# 4     2015-01-01 04:00:00            20264.0
# ...                   ...                ...
# 35055 2018-12-31 19:00:00            30653.0
# 35056 2018-12-31 20:00:00            29735.0
# 35057 2018-12-31 21:00:00            28071.0
# 35058 2018-12-31 22:00:00            25801.0
# 35059 2018-12-31 23:00:00            24455.0
#
# [35060 rows x 2 columns]

# %%
display(weather)
# Out:
#                      time        temp   humidity
# 0     2015-01-01 00:00:00  275.228480  61.163698
# 1     2015-01-01 01:00:00  274.489448  59.557082
# 2     2015-01-01 02:00:00  272.801766  57.517298
# 3     2015-01-01 03:00:00  271.734848  55.197876
# 4     2015-01-01 04:00:00  270.981817  53.560825
# ...                   ...         ...        ...
# 35055 2018-12-31 19:00:00  288.209055  60.602037
# 35056 2018-12-31 20:00:00  286.032653  64.531575
# 35057 2018-12-31 21:00:00  283.918582  67.866162
# 35058 2018-12-31 22:00:00  281.333997  64.230051
# 35059 2018-12-31 23:00:00  279.742236  58.474014
#
# [35060 rows x 3 columns]

# %%
df = demand.merge(weather,on="time",how="left")

# %%
df
# Out:
#                      time  total load actual        temp   humidity
# 0     2015-01-01 00:00:00            25385.0  275.228480  61.163698
# 1     2015-01-01 01:00:00            24382.0  274.489448  59.557082
# 2     2015-01-01 02:00:00            22734.0  272.801766  57.517298
# 3     2015-01-01 03:00:00            21286.0  271.734848  55.197876
# 4     2015-01-01 04:00:00            20264.0  270.981817  53.560825
# ...                   ...                ...         ...        ...
# 35055 2018-12-31 19:00:00            30653.0  288.209055  60.602037
# 35056 2018-12-31 20:00:00            29735.0  286.032653  64.531575
# 35057 2018-12-31 21:00:00            28071.0  283.918582  67.866162
# 35058 2018-12-31 22:00:00            25801.0  281.333997  64.230051
# 35059 2018-12-31 23:00:00            24455.0  279.742236  58.474014
#
# [35060 rows x 4 columns]

# %% [markdown]
# Add some seasonality and lagged features

# %%
df["hour"] = df["time"].dt.hour
df["day_of_week"] = df["time"].dt.dayofweek
df["day_of_month"] = df["time"].dt.day
df["year"] = df["time"].dt.year
df["month"] = df["time"].dt.month

# %% [markdown]
# Start adding daily lagged features from 2 because we have to post forecasts in day-ahead forecasting before the current day ends.

# %%
for daylag in range(2,8):
    df[f"daily_lag_{daylag}"] = df.groupby("hour")[TARGET].shift(daylag)
for weeklag in range(1,5):
    df[f"weekly_lag_{weeklag}"] = df.groupby(["day_of_week","hour"])[TARGET].shift(weeklag)

# %% [markdown]
# Check the missing values

# %%
display(df.isna().sum())
df.dropna(inplace=True)
# Out:
# time                   0
# total load actual     36
# temp                  36
# humidity              36
# hour                   0
# day_of_week            0
# day_of_month           0
# year                   0
# month                  0
# daily_lag_2           84
# daily_lag_3          108
# daily_lag_4          132
# daily_lag_5          156
# daily_lag_6          180
# daily_lag_7          204
# weekly_lag_1         204
# weekly_lag_2         372
# weekly_lag_3         540
# weekly_lag_4         708
# dtype: int64

# %% [markdown]
# There are 36 missing target values and missing values for lag features because there are no previous values of target for first period of our data. We can drop all the rows having at least 1 missing value.

# %%
display(df)
# Out:
#                      time  total load actual        temp   humidity  hour  \
# 672   2015-01-29 00:00:00            28577.0  280.421208  70.476678     0
# 673   2015-01-29 01:00:00            26313.0  278.927550  66.250178     1
# 674   2015-01-29 02:00:00            25016.0  277.404386  66.572630     2
# 675   2015-01-29 03:00:00            24408.0  276.945411  66.198729     3
# 676   2015-01-29 04:00:00            24295.0  280.113794  54.617724     4
# ...                   ...                ...         ...        ...   ...
# 35055 2018-12-31 19:00:00            30653.0  288.209055  60.602037    19
# 35056 2018-12-31 20:00:00            29735.0  286.032653  64.531575    20
# 35057 2018-12-31 21:00:00            28071.0  283.918582  67.866162    21
# 35058 2018-12-31 22:00:00            25801.0  281.333997  64.230051    22
# 35059 2018-12-31 23:00:00            24455.0  279.742236  58.474014    23
#
#        day_of_week  day_of_month  year  month  daily_lag_2  daily_lag_3  \
# 672              3            29  2015      1      28656.0      26853.0
# 673              3            29  2015      1      26315.0      24631.0
# 674              3            29  2015      1      24984.0      23303.0
# 675              3            29  2015      1      24506.0      22989.0
# 676              3            29  2015      1      24470.0      22879.0
# ...            ...           ...   ...    ...          ...          ...
# 35055            0            31  2018     12      30271.0      32728.0
# 35056            0            31  2018     12      30819.0      32642.0
# 35057            0            31  2018     12      30718.0      32155.0
# 35058            0            31  2018     12      29352.0      30428.0
# 35059            0            31  2018     12      27332.0      28015.0
#
#        daily_lag_4  daily_lag_5  daily_lag_6  daily_lag_7  weekly_lag_1  \
# 672        27877.0      30040.0      29746.0      29755.0       29755.0
# 673        25569.0      27485.0      27253.0      27137.0       27137.0
# 674        23794.0      25763.0      25770.0      25675.0       25675.0
# 675        22965.0      24786.0      25198.0      25103.0       25103.0
# 676        22428.0      24358.0      25081.0      24952.0       24952.0
# ...            ...          ...          ...          ...           ...
# 35055      32940.0      31167.0      25638.0      29570.0       29570.0
# 35056      33142.0      31577.0      26518.0      28474.0       28474.0
# 35057      32669.0      31459.0      26921.0      26583.0       26583.0
# 35058      30753.0      29812.0      26318.0      24287.0       24287.0
# 35059      27882.0      27108.0      24341.0      23231.0       23231.0
#
#        weekly_lag_2  weekly_lag_3  weekly_lag_4
# 672         27865.0       26788.0       25385.0
# 673         25617.0       25146.0       24382.0
# 674         24269.0       23889.0       22734.0
# 675         23940.0       23046.0       21286.0
# 676         23762.0       22587.0       20264.0
# ...             ...           ...           ...
# 35055       36987.0       25036.0       34188.0
# 35056       37448.0       27411.0       35768.0
# 35057       36205.0       27375.0       34789.0
# 35058       33444.0       26204.0       32301.0
# 35059       30171.0       24516.0       29336.0
#
# [34087 rows x 19 columns]

# %% [markdown]
# Name some feature groups seperately

# %%
seasonal_features = ["hour","day_of_month","day_of_week","month","year"]

lagged_features = [f"daily_lag_{lag}" for lag in range(2,8)] + [f"weekly_lag_{lag}" for lag in range(1,5)] 

feature_lists = {"with_weather":seasonal_features + lagged_features + ['temp',"humidity"],
                "without_weather":seasonal_features + lagged_features}

# %% [markdown]
# Define folds for time series cross validation

# %%
folds ={"1":{"valid_start":"2018-08-01 00:00:00","test_start":"2018-10-01 00:00:00","test_end":"2018-12-30 23:00:00"},
        "2":{"valid_start":"2018-07-01 00:00:00","test_start":"2018-09-01 00:00:00","test_end":"2018-11-30 23:00:00"},
        "3":{"valid_start":"2018-06-01 00:00:00","test_start":"2018-08-01 00:00:00","test_end":"2018-10-30 23:00:00"},
        "4":{"valid_start":"2018-05-01 00:00:00","test_start":"2018-07-01 00:00:00","test_end":"2018-09-30 23:00:00"},
        "5":{"valid_start":"2018-04-01 00:00:00","test_start":"2018-06-01 00:00:00","test_end":"2018-08-30 23:00:00"}
       }

# %% [markdown]
# Define evaluation function for mean absolute percentage error(mape)

# %%
def mape(y_pred, data):
    
    y_true = np.array((data.get_label()))
    
    ape = abs(y_true-y_pred)/y_true
    
    mape = 100*ape.mean()
    
    return 'mape', mape, False

# %% [markdown]
# Choose some parameters for lightgbm

# %%
parameters= {'nthread': -1, 
         'verbose': -1, 
         'boosting_type': 'gbdt', 
         'objective': 'regression_l1', 
         'max_bin': 64, 
         'extra_trees': False, 
         'num_leaves': 32, 
         'min_data_in_leaf': 15, 
         'min_data_in_bin': 15, 
         'learning_rate': 0.125, 
         'feature_fraction': 0.9, 
         'feature_fraction_bynode': 0.8, 
         'seed': 4, 
        }
iterations=10000

# %% [markdown]
# Now let's train and validate models for 5 different test periods and for 2 feature sets with and without weather features to see the effects of adding weather features on mape

# %%
# Define empty dictionaries to store training, validation, and testing data
trains={}
valids={}
tests={}

# Define empty dictionaries to store validation and testing scores for each feature
valid_scores_for_weather={}
test_scores_for_weather={}

# Loop through each feature list
for feature_key in feature_lists:
    
    # Get the list of features for the current key
    feature_list = feature_lists[feature_key]
    
    # Create empty dictionaries for each fold of the cross-validation
    trains[feature_key]={}
    valids[feature_key]={}
    tests[feature_key]={}
    valid_scores_for_weather[feature_key]={}
    test_scores_for_weather[feature_key]={}
    
    # Loop through each fold of the cross-validation
    for fold in folds:
        
        # Define the training, validation, and testing periods for the current fold
        train_period = (df["time"]<folds[f"{fold}"]["valid_start"]) 
        valid_period = (df["time"]>=folds[f"{fold}"]["valid_start"]) & (df["time"]<folds[f"{fold}"]["test_start"]) 
        test_period  = (df["time"]>=folds[f"{fold}"]["test_start"]) & (df["time"]<=folds[f"{fold}"]["test_end"])

        # Split the data into training, validation, and testing sets for the current fold
        train = df[train_period ].copy()
        train = train[~pd.isnull(train[TARGET])]
        valid = df[valid_period].copy()
        valid = valid[~pd.isnull(valid[TARGET])]
        test  = df[test_period].copy()
        test  = test[~pd.isnull(test[TARGET])]
        
        # Create X and y arrays for training, validation, and testing data
        X_train  = train[feature_list].copy()
        X_valid  = valid[feature_list].copy()
        X_test   = test[feature_list].copy()
        y_train = (train[TARGET].values)
        y_val   = (valid[TARGET].values)
        y_test   = (test[TARGET].values)

        # Create LightGBM datasets for training and validation
        train_dataset = lgb.Dataset(X_train, y_train)
        val_dataset   = lgb.Dataset(X_valid, y_val)
        
        # Initialize the "preds" columns in the validation and testing dataframes
        valid["preds"] = 0
        test["preds"] = 0
        
        # Loop through each seed for the current fold
        for seed in range(0,Seed):
            print(f"Seed-- {seed}")
            # Set the random seed for the current iteration
            parameters["seed"]  = seed
            
            # Train a LightGBM model on the current fold and seed
            model = lgb.train(params = parameters, 
                              train_set = train_dataset, 
                              valid_sets = [val_dataset], 
                              feval = mape,
                              early_stopping_rounds = 250,
                              verbose_eval = 100,
                              num_boost_round = iterations)

            # Make predictions on the validation and testing sets using the current model and seed
            valid["preds"] = valid["preds"] + model.predict(X_valid,num_iteration=model.best_iteration)
            test["preds"] = test["preds"] + model.predict(X_test,num_iteration=model.best_iteration)
        
        # Average the predictions across all seeds for the current fold
        valid["preds"] = valid["preds"]/Seed
        test["preds"] = test["preds"]/Seed
        
        # Calculate the mean absolute percentage error (MAPE) for the validation and testing sets
        valid["mape"] = 100*abs(valid[TARGET]-valid["preds"])/valid[TARGET]
        test["mape"] = 100*abs(test[TARGET]-test["preds"])/test[TARGET]
        
        # Store the mean validation and testing MAPE scores for the current feature and fold
        valid_scores_for_weather[feature_key][fold] =valid["mape"].mean()
        test_scores_for_weather[feature_key][fold] = test["mape"].mean()
# Out:
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# /home/semih/anaconda3/lib/python3.9/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/semih/anaconda3/lib/python3.9/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [100]	valid_0's l1: 747.144	valid_0's mape: 2.68408
# [200]	valid_0's l1: 719.138	valid_0's mape: 2.58149
# [300]	valid_0's l1: 709.917	valid_0's mape: 2.54273
# [400]	valid_0's l1: 708.22	valid_0's mape: 2.53495
# [500]	valid_0's l1: 704.394	valid_0's mape: 2.52017
# [600]	valid_0's l1: 700.742	valid_0's mape: 2.50731
# [700]	valid_0's l1: 699.347	valid_0's mape: 2.50127
# [800]	valid_0's l1: 698.499	valid_0's mape: 2.49699
# [900]	valid_0's l1: 693.692	valid_0's mape: 2.47931
# [1000]	valid_0's l1: 694.573	valid_0's mape: 2.48118
# [1100]	valid_0's l1: 692.866	valid_0's mape: 2.47458
# [1200]	valid_0's l1: 691.681	valid_0's mape: 2.46951
# [1300]	valid_0's l1: 691.763	valid_0's mape: 2.46988
# [1400]	valid_0's l1: 692.61	valid_0's mape: 2.4721
# Early stopping, best iteration is:
# [1241]	valid_0's l1: 690.863	valid_0's mape: 2.46655
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 769.368	valid_0's mape: 2.74162
# [200]	valid_0's l1: 728.516	valid_0's mape: 2.5906
# [300]	valid_0's l1: 711.081	valid_0's mape: 2.52668
# [400]	valid_0's l1: 704.756	valid_0's mape: 2.50292
# [500]	valid_0's l1: 699.407	valid_0's mape: 2.48291
# [600]	valid_0's l1: 698.224	valid_0's mape: 2.47846
# [700]	valid_0's l1: 695.487	valid_0's mape: 2.46913
# [800]	valid_0's l1: 693.888	valid_0's mape: 2.46387
# [900]	valid_0's l1: 694.368	valid_0's mape: 2.46492
# [1000]	valid_0's l1: 694.145	valid_0's mape: 2.46453
# [1100]	valid_0's l1: 692.889	valid_0's mape: 2.46042
# [1200]	valid_0's l1: 691.835	valid_0's mape: 2.45627
# [1300]	valid_0's l1: 690.944	valid_0's mape: 2.45309
# [1400]	valid_0's l1: 690.872	valid_0's mape: 2.45309
# [1500]	valid_0's l1: 689.834	valid_0's mape: 2.45011
# [1600]	valid_0's l1: 689.591	valid_0's mape: 2.44917
# [1700]	valid_0's l1: 689.646	valid_0's mape: 2.44951
# [1800]	valid_0's l1: 689.551	valid_0's mape: 2.44889
# [1900]	valid_0's l1: 688.679	valid_0's mape: 2.44571
# [2000]	valid_0's l1: 687.289	valid_0's mape: 2.43968
# [2100]	valid_0's l1: 687.213	valid_0's mape: 2.43928
# [2200]	valid_0's l1: 685.958	valid_0's mape: 2.43375
# [2300]	valid_0's l1: 684.809	valid_0's mape: 2.42983
# [2400]	valid_0's l1: 685.882	valid_0's mape: 2.43382
# [2500]	valid_0's l1: 684.691	valid_0's mape: 2.42886
# [2600]	valid_0's l1: 684.891	valid_0's mape: 2.4293
# Early stopping, best iteration is:
# [2431]	valid_0's l1: 684.285	valid_0's mape: 2.42697
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 758.021	valid_0's mape: 2.70334
# [200]	valid_0's l1: 723.598	valid_0's mape: 2.58127
# [300]	valid_0's l1: 717.259	valid_0's mape: 2.55776
# [400]	valid_0's l1: 713.912	valid_0's mape: 2.54546
# [500]	valid_0's l1: 708.908	valid_0's mape: 2.53001
# [600]	valid_0's l1: 707.52	valid_0's mape: 2.52582
# [700]	valid_0's l1: 703.663	valid_0's mape: 2.51205
# [800]	valid_0's l1: 699.939	valid_0's mape: 2.49934
# [900]	valid_0's l1: 697.76	valid_0's mape: 2.49173
# [1000]	valid_0's l1: 697.094	valid_0's mape: 2.48983
# [1100]	valid_0's l1: 698.004	valid_0's mape: 2.49303
# [1200]	valid_0's l1: 697.999	valid_0's mape: 2.49238
# [1300]	valid_0's l1: 698.249	valid_0's mape: 2.49379
# Early stopping, best iteration is:
# [1071]	valid_0's l1: 696.419	valid_0's mape: 2.48742
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 786.808	valid_0's mape: 2.7971
# [200]	valid_0's l1: 734.655	valid_0's mape: 2.61481
# [300]	valid_0's l1: 719.143	valid_0's mape: 2.56143
# [400]	valid_0's l1: 713.184	valid_0's mape: 2.54168
# [500]	valid_0's l1: 708.798	valid_0's mape: 2.52623
# [600]	valid_0's l1: 710.627	valid_0's mape: 2.53311
# [700]	valid_0's l1: 708.371	valid_0's mape: 2.52337
# [800]	valid_0's l1: 703.134	valid_0's mape: 2.50412
# [900]	valid_0's l1: 703.457	valid_0's mape: 2.50575
# [1000]	valid_0's l1: 702.931	valid_0's mape: 2.50349
# Early stopping, best iteration is:
# [818]	valid_0's l1: 702.352	valid_0's mape: 2.50191
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 763.929	valid_0's mape: 2.72602
# [200]	valid_0's l1: 733.191	valid_0's mape: 2.61951
# [300]	valid_0's l1: 718.371	valid_0's mape: 2.56289
# [400]	valid_0's l1: 714.431	valid_0's mape: 2.55041
# [500]	valid_0's l1: 708.102	valid_0's mape: 2.52829
# [600]	valid_0's l1: 703.282	valid_0's mape: 2.51003
# [700]	valid_0's l1: 698.924	valid_0's mape: 2.49059
# [800]	valid_0's l1: 696.962	valid_0's mape: 2.48316
# [900]	valid_0's l1: 696.889	valid_0's mape: 2.482
# [1000]	valid_0's l1: 695.795	valid_0's mape: 2.47666
# [1100]	valid_0's l1: 693.902	valid_0's mape: 2.46979
# [1200]	valid_0's l1: 691.013	valid_0's mape: 2.45841
# [1300]	valid_0's l1: 691.195	valid_0's mape: 2.45936
# [1400]	valid_0's l1: 692.151	valid_0's mape: 2.46351
# Early stopping, best iteration is:
# [1239]	valid_0's l1: 690.248	valid_0's mape: 2.45598
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 871.12	valid_0's mape: 3.10911
# [200]	valid_0's l1: 824.72	valid_0's mape: 2.93256
# [300]	valid_0's l1: 814.963	valid_0's mape: 2.89813
# [400]	valid_0's l1: 808.671	valid_0's mape: 2.87279
# [500]	valid_0's l1: 805.158	valid_0's mape: 2.86102
# [600]	valid_0's l1: 800.489	valid_0's mape: 2.8457
# [700]	valid_0's l1: 796.747	valid_0's mape: 2.83199
# [800]	valid_0's l1: 795.33	valid_0's mape: 2.8278
# [900]	valid_0's l1: 793.76	valid_0's mape: 2.82308
# [1000]	valid_0's l1: 793.165	valid_0's mape: 2.81985
# [1100]	valid_0's l1: 792.883	valid_0's mape: 2.81892
# [1200]	valid_0's l1: 792.095	valid_0's mape: 2.81551
# [1300]	valid_0's l1: 791.572	valid_0's mape: 2.81624
# [1400]	valid_0's l1: 790.616	valid_0's mape: 2.81195
# [1500]	valid_0's l1: 790.645	valid_0's mape: 2.81203
# [1600]	valid_0's l1: 790.752	valid_0's mape: 2.81268
# [1700]	valid_0's l1: 789.69	valid_0's mape: 2.80939
# [1800]	valid_0's l1: 789.659	valid_0's mape: 2.80915
# [1900]	valid_0's l1: 790.363	valid_0's mape: 2.81156
# Early stopping, best iteration is:
# [1716]	valid_0's l1: 789.272	valid_0's mape: 2.80785
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 849.747	valid_0's mape: 3.03018
# [200]	valid_0's l1: 809.165	valid_0's mape: 2.87872
# [300]	valid_0's l1: 802.651	valid_0's mape: 2.85063
# [400]	valid_0's l1: 793.58	valid_0's mape: 2.81833
# [500]	valid_0's l1: 792.889	valid_0's mape: 2.81744
# [600]	valid_0's l1: 790.832	valid_0's mape: 2.80887
# [700]	valid_0's l1: 789.27	valid_0's mape: 2.80354
# [800]	valid_0's l1: 789.089	valid_0's mape: 2.80276
# [900]	valid_0's l1: 789.96	valid_0's mape: 2.80678
# [1000]	valid_0's l1: 788.449	valid_0's mape: 2.80117
# [1100]	valid_0's l1: 788.153	valid_0's mape: 2.79975
# [1200]	valid_0's l1: 786.456	valid_0's mape: 2.79304
# [1300]	valid_0's l1: 783.954	valid_0's mape: 2.78424
# [1400]	valid_0's l1: 782.372	valid_0's mape: 2.77811
# [1500]	valid_0's l1: 781.569	valid_0's mape: 2.77545
# [1600]	valid_0's l1: 781.716	valid_0's mape: 2.77559
# [1700]	valid_0's l1: 782.231	valid_0's mape: 2.77655
# [1800]	valid_0's l1: 783.743	valid_0's mape: 2.78205
# Early stopping, best iteration is:
# [1628]	valid_0's l1: 780.953	valid_0's mape: 2.77265
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 840.046	valid_0's mape: 2.99782
# [200]	valid_0's l1: 816.783	valid_0's mape: 2.90805
# [300]	valid_0's l1: 816.42	valid_0's mape: 2.9074
# [400]	valid_0's l1: 811.882	valid_0's mape: 2.89195
# [500]	valid_0's l1: 806.969	valid_0's mape: 2.87469
# [600]	valid_0's l1: 805.182	valid_0's mape: 2.86813
# [700]	valid_0's l1: 804.253	valid_0's mape: 2.86612
# [800]	valid_0's l1: 802.229	valid_0's mape: 2.85927
# [900]	valid_0's l1: 803.053	valid_0's mape: 2.86189
# [1000]	valid_0's l1: 801.319	valid_0's mape: 2.85384
# [1100]	valid_0's l1: 802.363	valid_0's mape: 2.85814
# [1200]	valid_0's l1: 801.519	valid_0's mape: 2.85476
# Early stopping, best iteration is:
# [1017]	valid_0's l1: 800.768	valid_0's mape: 2.85166
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 867.798	valid_0's mape: 3.08983
# [200]	valid_0's l1: 834.263	valid_0's mape: 2.9647
# [300]	valid_0's l1: 825.71	valid_0's mape: 2.93488
# [400]	valid_0's l1: 817.86	valid_0's mape: 2.90701
# [500]	valid_0's l1: 819.332	valid_0's mape: 2.91096
# [600]	valid_0's l1: 816.689	valid_0's mape: 2.90041
# [700]	valid_0's l1: 814.004	valid_0's mape: 2.89278
# [800]	valid_0's l1: 814.897	valid_0's mape: 2.89698
# [900]	valid_0's l1: 812.976	valid_0's mape: 2.88823
# Early stopping, best iteration is:
# [652]	valid_0's l1: 811.615	valid_0's mape: 2.88402
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 856.641	valid_0's mape: 3.0413
# [200]	valid_0's l1: 842.37	valid_0's mape: 2.9844
# [300]	valid_0's l1: 839.379	valid_0's mape: 2.96928
# [400]	valid_0's l1: 836.877	valid_0's mape: 2.96447
# [500]	valid_0's l1: 838.589	valid_0's mape: 2.97177
# Early stopping, best iteration is:
# [323]	valid_0's l1: 834.621	valid_0's mape: 2.95551
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 774.263	valid_0's mape: 2.71554
# [200]	valid_0's l1: 733.366	valid_0's mape: 2.57197
# [300]	valid_0's l1: 729.823	valid_0's mape: 2.55538
# [400]	valid_0's l1: 725.144	valid_0's mape: 2.53606
# [500]	valid_0's l1: 725.602	valid_0's mape: 2.53755
# [600]	valid_0's l1: 722.274	valid_0's mape: 2.52575
# [700]	valid_0's l1: 723.488	valid_0's mape: 2.52959
# Early stopping, best iteration is:
# [451]	valid_0's l1: 721.048	valid_0's mape: 2.52126
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 764.671	valid_0's mape: 2.67012
# [200]	valid_0's l1: 742.69	valid_0's mape: 2.59089
# [300]	valid_0's l1: 733.225	valid_0's mape: 2.55861
# [400]	valid_0's l1: 729.835	valid_0's mape: 2.54735
# [500]	valid_0's l1: 726.776	valid_0's mape: 2.53545
# [600]	valid_0's l1: 724.232	valid_0's mape: 2.52579
# [700]	valid_0's l1: 725.599	valid_0's mape: 2.53153
# [800]	valid_0's l1: 726.925	valid_0's mape: 2.53706
# Early stopping, best iteration is:
# [610]	valid_0's l1: 723.424	valid_0's mape: 2.52349
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 781.243	valid_0's mape: 2.73535
# [200]	valid_0's l1: 759.318	valid_0's mape: 2.66638
# [300]	valid_0's l1: 753.36	valid_0's mape: 2.6439
# [400]	valid_0's l1: 745.276	valid_0's mape: 2.61928
# [500]	valid_0's l1: 747.403	valid_0's mape: 2.63288
# [600]	valid_0's l1: 747.804	valid_0's mape: 2.63276
# Early stopping, best iteration is:
# [438]	valid_0's l1: 740.004	valid_0's mape: 2.6054
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 778.494	valid_0's mape: 2.722
# [200]	valid_0's l1: 756.146	valid_0's mape: 2.64178
# [300]	valid_0's l1: 749.028	valid_0's mape: 2.61888
# [400]	valid_0's l1: 745.501	valid_0's mape: 2.6059
# [500]	valid_0's l1: 743.348	valid_0's mape: 2.59812
# [600]	valid_0's l1: 744.077	valid_0's mape: 2.6005
# [700]	valid_0's l1: 742.997	valid_0's mape: 2.5973
# [800]	valid_0's l1: 741.835	valid_0's mape: 2.59335
# [900]	valid_0's l1: 741.144	valid_0's mape: 2.59041
# [1000]	valid_0's l1: 736.692	valid_0's mape: 2.57964
# [1100]	valid_0's l1: 736.736	valid_0's mape: 2.58006
# [1200]	valid_0's l1: 735.959	valid_0's mape: 2.57723
# [1300]	valid_0's l1: 737.518	valid_0's mape: 2.58132
# [1400]	valid_0's l1: 737.258	valid_0's mape: 2.58002
# Early stopping, best iteration is:
# [1182]	valid_0's l1: 735.37	valid_0's mape: 2.57549
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 796.402	valid_0's mape: 2.78623
# [200]	valid_0's l1: 765.509	valid_0's mape: 2.67807
# [300]	valid_0's l1: 761.987	valid_0's mape: 2.65818
# [400]	valid_0's l1: 755.499	valid_0's mape: 2.63564
# [500]	valid_0's l1: 753.988	valid_0's mape: 2.63032
# [600]	valid_0's l1: 755.38	valid_0's mape: 2.63334
# [700]	valid_0's l1: 756.968	valid_0's mape: 2.63763
# [800]	valid_0's l1: 753.256	valid_0's mape: 2.62362
# Early stopping, best iteration is:
# [558]	valid_0's l1: 751.351	valid_0's mape: 2.62092
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 788.401	valid_0's mape: 2.75847
# [200]	valid_0's l1: 781.154	valid_0's mape: 2.72481
# [300]	valid_0's l1: 767.363	valid_0's mape: 2.67278
# [400]	valid_0's l1: 764.533	valid_0's mape: 2.65912
# [500]	valid_0's l1: 763.205	valid_0's mape: 2.65323
# [600]	valid_0's l1: 762.825	valid_0's mape: 2.64925
# [700]	valid_0's l1: 761.784	valid_0's mape: 2.64108
# [800]	valid_0's l1: 761.154	valid_0's mape: 2.63719
# [900]	valid_0's l1: 760.201	valid_0's mape: 2.63449
# [1000]	valid_0's l1: 762.806	valid_0's mape: 2.64278
# Early stopping, best iteration is:
# [778]	valid_0's l1: 758.304	valid_0's mape: 2.62674
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 743.745	valid_0's mape: 2.58179
# [200]	valid_0's l1: 723.547	valid_0's mape: 2.50903
# [300]	valid_0's l1: 718.976	valid_0's mape: 2.4936
# [400]	valid_0's l1: 711.715	valid_0's mape: 2.46699
# [500]	valid_0's l1: 714.253	valid_0's mape: 2.47436
# [600]	valid_0's l1: 715.333	valid_0's mape: 2.47767
# [700]	valid_0's l1: 716.42	valid_0's mape: 2.48121
# Early stopping, best iteration is:
# [496]	valid_0's l1: 710.558	valid_0's mape: 2.46218
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 785.844	valid_0's mape: 2.72329
# [200]	valid_0's l1: 757.607	valid_0's mape: 2.61978
# [300]	valid_0's l1: 747.017	valid_0's mape: 2.57675
# [400]	valid_0's l1: 742.257	valid_0's mape: 2.55922
# [500]	valid_0's l1: 741.621	valid_0's mape: 2.56003
# [600]	valid_0's l1: 741.96	valid_0's mape: 2.56276
# [700]	valid_0's l1: 738.881	valid_0's mape: 2.55293
# [800]	valid_0's l1: 738.132	valid_0's mape: 2.55004
# [900]	valid_0's l1: 735.073	valid_0's mape: 2.539
# [1000]	valid_0's l1: 735.881	valid_0's mape: 2.54173
# [1100]	valid_0's l1: 734.323	valid_0's mape: 2.53665
# [1200]	valid_0's l1: 737.692	valid_0's mape: 2.54863
# [1300]	valid_0's l1: 735.92	valid_0's mape: 2.54358
# Early stopping, best iteration is:
# [1111]	valid_0's l1: 734.091	valid_0's mape: 2.53589
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 781.818	valid_0's mape: 2.70985
# [200]	valid_0's l1: 770.311	valid_0's mape: 2.65812
# [300]	valid_0's l1: 768.29	valid_0's mape: 2.64528
# [400]	valid_0's l1: 760.533	valid_0's mape: 2.61669
# [500]	valid_0's l1: 757.435	valid_0's mape: 2.60401
# [600]	valid_0's l1: 758.415	valid_0's mape: 2.60671
# [700]	valid_0's l1: 759.537	valid_0's mape: 2.60894
# Early stopping, best iteration is:
# [535]	valid_0's l1: 756.824	valid_0's mape: 2.6023
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 761.316	valid_0's mape: 2.6501
# [200]	valid_0's l1: 737.528	valid_0's mape: 2.56311
# [300]	valid_0's l1: 735.41	valid_0's mape: 2.55087
# [400]	valid_0's l1: 731.519	valid_0's mape: 2.53726
# [500]	valid_0's l1: 731.364	valid_0's mape: 2.53437
# [600]	valid_0's l1: 730.871	valid_0's mape: 2.53324
# [700]	valid_0's l1: 733.372	valid_0's mape: 2.54198
# [800]	valid_0's l1: 732.907	valid_0's mape: 2.53827
# Early stopping, best iteration is:
# [558]	valid_0's l1: 729.415	valid_0's mape: 2.52839
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 917.001	valid_0's mape: 3.28586
# [200]	valid_0's l1: 927.018	valid_0's mape: 3.31862
# [300]	valid_0's l1: 933.991	valid_0's mape: 3.34255
# Early stopping, best iteration is:
# [90]	valid_0's l1: 901.763	valid_0's mape: 3.23053
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 894.749	valid_0's mape: 3.21685
# [200]	valid_0's l1: 901.987	valid_0's mape: 3.23776
# [300]	valid_0's l1: 928.071	valid_0's mape: 3.32525
# Early stopping, best iteration is:
# [99]	valid_0's l1: 894.056	valid_0's mape: 3.21475
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1029.41	valid_0's mape: 3.69765
# [200]	valid_0's l1: 1030.35	valid_0's mape: 3.68976
# [300]	valid_0's l1: 1049.89	valid_0's mape: 3.75385
# Early stopping, best iteration is:
# [54]	valid_0's l1: 969.888	valid_0's mape: 3.48247
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 933.1	valid_0's mape: 3.36481
# [200]	valid_0's l1: 928.123	valid_0's mape: 3.34038
# [300]	valid_0's l1: 922.464	valid_0's mape: 3.31745
# [400]	valid_0's l1: 942.385	valid_0's mape: 3.39025
# [500]	valid_0's l1: 939.097	valid_0's mape: 3.37471
# Early stopping, best iteration is:
# [302]	valid_0's l1: 920.939	valid_0's mape: 3.31198
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 932.255	valid_0's mape: 3.34101
# [200]	valid_0's l1: 980.82	valid_0's mape: 3.52102
# [300]	valid_0's l1: 989.295	valid_0's mape: 3.54821
# Early stopping, best iteration is:
# [67]	valid_0's l1: 906.85	valid_0's mape: 3.24811
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1389.08	valid_0's mape: 4.75003
# [200]	valid_0's l1: 1333.56	valid_0's mape: 4.55381
# [300]	valid_0's l1: 1321.67	valid_0's mape: 4.51069
# [400]	valid_0's l1: 1322.83	valid_0's mape: 4.50937
# [500]	valid_0's l1: 1310.23	valid_0's mape: 4.46465
# [600]	valid_0's l1: 1303.5	valid_0's mape: 4.44113
# [700]	valid_0's l1: 1292.82	valid_0's mape: 4.40354
# [800]	valid_0's l1: 1292.52	valid_0's mape: 4.40253
# [900]	valid_0's l1: 1297.87	valid_0's mape: 4.41974
# Early stopping, best iteration is:
# [727]	valid_0's l1: 1291.56	valid_0's mape: 4.39966
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1429.14	valid_0's mape: 4.87171
# [200]	valid_0's l1: 1388.82	valid_0's mape: 4.71515
# [300]	valid_0's l1: 1380.92	valid_0's mape: 4.67866
# [400]	valid_0's l1: 1368.88	valid_0's mape: 4.63767
# [500]	valid_0's l1: 1351.24	valid_0's mape: 4.57321
# [600]	valid_0's l1: 1346.07	valid_0's mape: 4.55239
# [700]	valid_0's l1: 1339.92	valid_0's mape: 4.52929
# [800]	valid_0's l1: 1333.32	valid_0's mape: 4.50716
# [900]	valid_0's l1: 1333.53	valid_0's mape: 4.50612
# [1000]	valid_0's l1: 1334.12	valid_0's mape: 4.50692
# Early stopping, best iteration is:
# [808]	valid_0's l1: 1332.88	valid_0's mape: 4.50553
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1385.04	valid_0's mape: 4.71464
# [200]	valid_0's l1: 1344.01	valid_0's mape: 4.57084
# [300]	valid_0's l1: 1339.9	valid_0's mape: 4.54905
# [400]	valid_0's l1: 1327.54	valid_0's mape: 4.50054
# [500]	valid_0's l1: 1321.01	valid_0's mape: 4.47274
# [600]	valid_0's l1: 1311.9	valid_0's mape: 4.44122
# [700]	valid_0's l1: 1305.04	valid_0's mape: 4.4099
# [800]	valid_0's l1: 1304.05	valid_0's mape: 4.40844
# [900]	valid_0's l1: 1302.06	valid_0's mape: 4.39921
# [1000]	valid_0's l1: 1297.73	valid_0's mape: 4.38494
# [1100]	valid_0's l1: 1296.3	valid_0's mape: 4.37784
# [1200]	valid_0's l1: 1292.5	valid_0's mape: 4.36598
# [1300]	valid_0's l1: 1295.75	valid_0's mape: 4.37563
# [1400]	valid_0's l1: 1296.8	valid_0's mape: 4.37756
# Early stopping, best iteration is:
# [1191]	valid_0's l1: 1292.19	valid_0's mape: 4.36463
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1431.64	valid_0's mape: 4.89199
# [200]	valid_0's l1: 1406.07	valid_0's mape: 4.78067
# [300]	valid_0's l1: 1380.93	valid_0's mape: 4.69629
# [400]	valid_0's l1: 1371.34	valid_0's mape: 4.66469
# [500]	valid_0's l1: 1349	valid_0's mape: 4.59036
# [600]	valid_0's l1: 1341.88	valid_0's mape: 4.5686
# [700]	valid_0's l1: 1342.2	valid_0's mape: 4.56417
# [800]	valid_0's l1: 1331.15	valid_0's mape: 4.52734
# [900]	valid_0's l1: 1328.09	valid_0's mape: 4.51874
# [1000]	valid_0's l1: 1328.1	valid_0's mape: 4.51651
# [1100]	valid_0's l1: 1328.19	valid_0's mape: 4.51354
# [1200]	valid_0's l1: 1327.13	valid_0's mape: 4.50905
# [1300]	valid_0's l1: 1325.4	valid_0's mape: 4.50224
# [1400]	valid_0's l1: 1325.6	valid_0's mape: 4.50032
# [1500]	valid_0's l1: 1319.77	valid_0's mape: 4.4813
# [1600]	valid_0's l1: 1318.42	valid_0's mape: 4.47746
# [1700]	valid_0's l1: 1318.62	valid_0's mape: 4.47738
# [1800]	valid_0's l1: 1318.43	valid_0's mape: 4.47581
# Early stopping, best iteration is:
# [1608]	valid_0's l1: 1318.24	valid_0's mape: 4.47686
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1388.96	valid_0's mape: 4.72933
# [200]	valid_0's l1: 1387.96	valid_0's mape: 4.72479
# [300]	valid_0's l1: 1349.6	valid_0's mape: 4.60085
# [400]	valid_0's l1: 1330.21	valid_0's mape: 4.52336
# [500]	valid_0's l1: 1326.89	valid_0's mape: 4.50328
# [600]	valid_0's l1: 1321.91	valid_0's mape: 4.48859
# [700]	valid_0's l1: 1318.59	valid_0's mape: 4.47347
# [800]	valid_0's l1: 1319.62	valid_0's mape: 4.47487
# [900]	valid_0's l1: 1319.42	valid_0's mape: 4.4742
# [1000]	valid_0's l1: 1312.86	valid_0's mape: 4.45077
# [1100]	valid_0's l1: 1301.85	valid_0's mape: 4.41296
# [1200]	valid_0's l1: 1299.74	valid_0's mape: 4.40702
# [1300]	valid_0's l1: 1296.4	valid_0's mape: 4.39694
# [1400]	valid_0's l1: 1295.47	valid_0's mape: 4.39371
# [1500]	valid_0's l1: 1293.45	valid_0's mape: 4.38776
# [1600]	valid_0's l1: 1293.98	valid_0's mape: 4.3895
# [1700]	valid_0's l1: 1294.99	valid_0's mape: 4.39435
# Early stopping, best iteration is:
# [1537]	valid_0's l1: 1292.43	valid_0's mape: 4.38463
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1373.5	valid_0's mape: 4.71558
# [200]	valid_0's l1: 1330.14	valid_0's mape: 4.56298
# [300]	valid_0's l1: 1314.06	valid_0's mape: 4.50787
# [400]	valid_0's l1: 1288.16	valid_0's mape: 4.42473
# [500]	valid_0's l1: 1274.91	valid_0's mape: 4.38528
# [600]	valid_0's l1: 1272.84	valid_0's mape: 4.37939
# [700]	valid_0's l1: 1268.84	valid_0's mape: 4.36393
# [800]	valid_0's l1: 1269.55	valid_0's mape: 4.36506
# [900]	valid_0's l1: 1261.66	valid_0's mape: 4.33647
# [1000]	valid_0's l1: 1260.92	valid_0's mape: 4.3326
# [1100]	valid_0's l1: 1255.71	valid_0's mape: 4.31618
# [1200]	valid_0's l1: 1253.02	valid_0's mape: 4.3076
# [1300]	valid_0's l1: 1254.35	valid_0's mape: 4.3124
# [1400]	valid_0's l1: 1255.55	valid_0's mape: 4.31619
# Early stopping, best iteration is:
# [1206]	valid_0's l1: 1252.67	valid_0's mape: 4.30645
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1348.09	valid_0's mape: 4.64739
# [200]	valid_0's l1: 1276.75	valid_0's mape: 4.39834
# [300]	valid_0's l1: 1256.09	valid_0's mape: 4.33443
# [400]	valid_0's l1: 1247.31	valid_0's mape: 4.30252
# [500]	valid_0's l1: 1242.34	valid_0's mape: 4.28011
# [600]	valid_0's l1: 1242.25	valid_0's mape: 4.27983
# [700]	valid_0's l1: 1236.2	valid_0's mape: 4.25703
# [800]	valid_0's l1: 1228.84	valid_0's mape: 4.23062
# [900]	valid_0's l1: 1226.41	valid_0's mape: 4.22057
# [1000]	valid_0's l1: 1221.99	valid_0's mape: 4.20677
# [1100]	valid_0's l1: 1223.34	valid_0's mape: 4.21264
# [1200]	valid_0's l1: 1224.27	valid_0's mape: 4.21382
# Early stopping, best iteration is:
# [1003]	valid_0's l1: 1221.9	valid_0's mape: 4.20656
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1305.37	valid_0's mape: 4.50705
# [200]	valid_0's l1: 1264.8	valid_0's mape: 4.37748
# [300]	valid_0's l1: 1251.07	valid_0's mape: 4.31391
# [400]	valid_0's l1: 1244.03	valid_0's mape: 4.28349
# [500]	valid_0's l1: 1230.92	valid_0's mape: 4.24454
# [600]	valid_0's l1: 1226.29	valid_0's mape: 4.22637
# [700]	valid_0's l1: 1214.21	valid_0's mape: 4.18781
# [800]	valid_0's l1: 1198.94	valid_0's mape: 4.13567
# [900]	valid_0's l1: 1197.17	valid_0's mape: 4.12891
# [1000]	valid_0's l1: 1198.23	valid_0's mape: 4.13106
# [1100]	valid_0's l1: 1198.83	valid_0's mape: 4.13125
# Early stopping, best iteration is:
# [931]	valid_0's l1: 1195.93	valid_0's mape: 4.12459
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1317.09	valid_0's mape: 4.54279
# [200]	valid_0's l1: 1241.18	valid_0's mape: 4.29573
# [300]	valid_0's l1: 1204.04	valid_0's mape: 4.1708
# [400]	valid_0's l1: 1190.96	valid_0's mape: 4.12297
# [500]	valid_0's l1: 1185.92	valid_0's mape: 4.10791
# [600]	valid_0's l1: 1180.04	valid_0's mape: 4.08775
# [700]	valid_0's l1: 1174.99	valid_0's mape: 4.07217
# [800]	valid_0's l1: 1176.45	valid_0's mape: 4.07771
# [900]	valid_0's l1: 1175.67	valid_0's mape: 4.07337
# [1000]	valid_0's l1: 1179.74	valid_0's mape: 4.08246
# [1100]	valid_0's l1: 1174.8	valid_0's mape: 4.06693
# [1200]	valid_0's l1: 1175.21	valid_0's mape: 4.06998
# [1300]	valid_0's l1: 1172.94	valid_0's mape: 4.06145
# [1400]	valid_0's l1: 1168.79	valid_0's mape: 4.04856
# [1500]	valid_0's l1: 1167.43	valid_0's mape: 4.04362
# [1600]	valid_0's l1: 1167.18	valid_0's mape: 4.04238
# [1700]	valid_0's l1: 1165.65	valid_0's mape: 4.03709
# [1800]	valid_0's l1: 1164.24	valid_0's mape: 4.03115
# [1900]	valid_0's l1: 1163.58	valid_0's mape: 4.02826
# [2000]	valid_0's l1: 1163.49	valid_0's mape: 4.02737
# [2100]	valid_0's l1: 1160.96	valid_0's mape: 4.02047
# [2200]	valid_0's l1: 1160.26	valid_0's mape: 4.01839
# [2300]	valid_0's l1: 1159.7	valid_0's mape: 4.01508
# [2400]	valid_0's l1: 1159.98	valid_0's mape: 4.01632
# [2500]	valid_0's l1: 1160.22	valid_0's mape: 4.01477
# [2600]	valid_0's l1: 1160.59	valid_0's mape: 4.01593
# Early stopping, best iteration is:
# [2431]	valid_0's l1: 1158.75	valid_0's mape: 4.01232
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1376.51	valid_0's mape: 4.7271
# [200]	valid_0's l1: 1308.9	valid_0's mape: 4.48806
# [300]	valid_0's l1: 1300.73	valid_0's mape: 4.45182
# [400]	valid_0's l1: 1292.61	valid_0's mape: 4.42301
# [500]	valid_0's l1: 1280.88	valid_0's mape: 4.38835
# [600]	valid_0's l1: 1276.73	valid_0's mape: 4.37708
# [700]	valid_0's l1: 1274.51	valid_0's mape: 4.36928
# [800]	valid_0's l1: 1277.42	valid_0's mape: 4.38047
# [900]	valid_0's l1: 1279.85	valid_0's mape: 4.39071
# [1000]	valid_0's l1: 1277.5	valid_0's mape: 4.38221
# [1100]	valid_0's l1: 1275.15	valid_0's mape: 4.3732
# Early stopping, best iteration is:
# [856]	valid_0's l1: 1272.49	valid_0's mape: 4.36482
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1412.91	valid_0's mape: 4.85288
# [200]	valid_0's l1: 1394.85	valid_0's mape: 4.78364
# [300]	valid_0's l1: 1396.5	valid_0's mape: 4.77562
# [400]	valid_0's l1: 1416.7	valid_0's mape: 4.8317
# Early stopping, best iteration is:
# [226]	valid_0's l1: 1387.7	valid_0's mape: 4.75419
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1424.98	valid_0's mape: 4.8904
# [200]	valid_0's l1: 1413.74	valid_0's mape: 4.85469
# [300]	valid_0's l1: 1439.42	valid_0's mape: 4.92996
# [400]	valid_0's l1: 1443.77	valid_0's mape: 4.94677
# Early stopping, best iteration is:
# [156]	valid_0's l1: 1404.55	valid_0's mape: 4.82711
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1366.29	valid_0's mape: 4.66855
# [200]	valid_0's l1: 1333.18	valid_0's mape: 4.54995
# [300]	valid_0's l1: 1330.26	valid_0's mape: 4.53969
# [400]	valid_0's l1: 1314.14	valid_0's mape: 4.49065
# [500]	valid_0's l1: 1311.43	valid_0's mape: 4.48164
# [600]	valid_0's l1: 1316.37	valid_0's mape: 4.50231
# [700]	valid_0's l1: 1315.25	valid_0's mape: 4.49709
# Early stopping, best iteration is:
# [506]	valid_0's l1: 1310.74	valid_0's mape: 4.4794
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1409.31	valid_0's mape: 4.81216
# [200]	valid_0's l1: 1370.18	valid_0's mape: 4.68273
# [300]	valid_0's l1: 1390.5	valid_0's mape: 4.73561
# [400]	valid_0's l1: 1388.96	valid_0's mape: 4.73267
# Early stopping, best iteration is:
# [209]	valid_0's l1: 1363.27	valid_0's mape: 4.6574
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1408.45	valid_0's mape: 4.81267
# [200]	valid_0's l1: 1394.27	valid_0's mape: 4.75944
# [300]	valid_0's l1: 1383.17	valid_0's mape: 4.72064
# [400]	valid_0's l1: 1385.33	valid_0's mape: 4.72936
# Early stopping, best iteration is:
# [248]	valid_0's l1: 1379.06	valid_0's mape: 4.70774
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1366.96	valid_0's mape: 4.64282
# [200]	valid_0's l1: 1342	valid_0's mape: 4.56366
# [300]	valid_0's l1: 1342.43	valid_0's mape: 4.56432
# [400]	valid_0's l1: 1347.61	valid_0's mape: 4.58115
# Early stopping, best iteration is:
# [243]	valid_0's l1: 1340.26	valid_0's mape: 4.55598
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1338.12	valid_0's mape: 4.56018
# [200]	valid_0's l1: 1365.75	valid_0's mape: 4.63854
# [300]	valid_0's l1: 1375.71	valid_0's mape: 4.66794
# Early stopping, best iteration is:
# [99]	valid_0's l1: 1337.54	valid_0's mape: 4.5584
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1367.19	valid_0's mape: 4.64763
# [200]	valid_0's l1: 1374.66	valid_0's mape: 4.67618
# [300]	valid_0's l1: 1385.88	valid_0's mape: 4.71509
# Early stopping, best iteration is:
# [135]	valid_0's l1: 1360.09	valid_0's mape: 4.61789
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1338.35	valid_0's mape: 4.55075
# [200]	valid_0's l1: 1342.82	valid_0's mape: 4.56447
# [300]	valid_0's l1: 1360.03	valid_0's mape: 4.62399
# Early stopping, best iteration is:
# [132]	valid_0's l1: 1324.73	valid_0's mape: 4.51059
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1403.41	valid_0's mape: 4.77912
# [200]	valid_0's l1: 1409.59	valid_0's mape: 4.7958
# [300]	valid_0's l1: 1422.85	valid_0's mape: 4.83574
# Early stopping, best iteration is:
# [126]	valid_0's l1: 1401.7	valid_0's mape: 4.76479
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1274.65	valid_0's mape: 4.50182
# [200]	valid_0's l1: 1287.48	valid_0's mape: 4.56428
# [300]	valid_0's l1: 1298.69	valid_0's mape: 4.59877
# Early stopping, best iteration is:
# [122]	valid_0's l1: 1254.5	valid_0's mape: 4.43932
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1256.76	valid_0's mape: 4.43277
# [200]	valid_0's l1: 1243.78	valid_0's mape: 4.38848
# [300]	valid_0's l1: 1252.14	valid_0's mape: 4.42212
# Early stopping, best iteration is:
# [70]	valid_0's l1: 1233.59	valid_0's mape: 4.3562
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1221.13	valid_0's mape: 4.32502
# [200]	valid_0's l1: 1248.57	valid_0's mape: 4.41398
# [300]	valid_0's l1: 1232.43	valid_0's mape: 4.35988
# Early stopping, best iteration is:
# [146]	valid_0's l1: 1213.06	valid_0's mape: 4.29511
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1256.09	valid_0's mape: 4.44414
# [200]	valid_0's l1: 1278.76	valid_0's mape: 4.50363
# [300]	valid_0's l1: 1303.91	valid_0's mape: 4.59284
# Early stopping, best iteration is:
# [110]	valid_0's l1: 1251.9	valid_0's mape: 4.42827
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1248.59	valid_0's mape: 4.41446
# [200]	valid_0's l1: 1299.78	valid_0's mape: 4.58541
# [300]	valid_0's l1: 1335.74	valid_0's mape: 4.70813
# Early stopping, best iteration is:
# [101]	valid_0's l1: 1248.55	valid_0's mape: 4.41372

# %%
test_scores_for_weather
# Out:
# {'with_weather': {'1': 3.855749608723726,
#   '2': 3.430391032586607,
#   '3': 3.075130452574435,
#   '4': 2.7546012511969917,
#   '5': 3.1829470524856323},
#  'without_weather': {'1': 4.452563485393113,
#   '2': 4.1647003054719445,
#   '3': 4.617499644050344,
#   '4': 4.633383720670435,
#   '5': 4.703354333831305}}

# %%
x_with_weather = np.arange(5)
x_without_weather = x_with_weather+0.25
y_with_weather = test_scores_for_weather["with_weather"].values()
y_without_weather = test_scores_for_weather["without_weather"].values()
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(x_with_weather, y_with_weather, width=0.25, label='with_weather')
ax.bar(x_without_weather, y_without_weather, width=0.25, label='without_weather')
ax.set_xticks(x_with_weather + 0.25)
ax.set_xticklabels([f"Fold {i+1}" for i in range(len(y_without_weather))])
ax.set_xlabel('Folds')
ax.set_ylabel('Test scores')
ax.legend()
plt.show()

# %% [markdown]
# As you can see in the chart above adding weather features improves model performance across all test periods. Hence we can start considering using hourly temperature and humidity values in our demand forecasting model. The results are promising but there is a significant difrerence between the way we used the 2 feautures above and the way we would try to forecast the electricity consumption for tomorrow. If you were in 2018 and you had decided to use 2 new features forecasted by 3rd party data source, as we do above, you probably could only get actual values of features for your historical data. Therefore, the test results don't include the forecasting error of data source if we haven't already stored daily forecasts. To not be too optimistic and accurately simulate the daily forecasting procees  we can add some noise to the test data with the same error distribution of our data source. When we add noise to the test sets model performance will decrease as the error value increases.
#
# At this moment, the key question arises. There assumed an normally distributed error in the test set, should we add noise to actual values of the 2 features in the training data in the same distribution of test set error. Notice that because we don't have historical forecasts of temperature and humidity for 2018, we treat the noise we are going add to test data as the actual error of weather forecasting source and consider to add a similar error to the train data to improve the performance or robustness of forecasting model.
#
# In the code below we benchmark the model that we train with the actual values of weather features, with the model that we train with noised values of weather features for different normally distributed errors having different standart deviations.

# %%
# Define the list of features to use
feature_list = feature_lists["with_weather"]

# Define dictionaries to store the validation and testing scores, as well as the training, validation, and testing sets
valid_scores={}
test_scores={}
trains={}
valids={}
tests={}

# Define a range of standard deviations to add noise to the testing set
errors=np.array([0.5,1,1.5,2,2.5,3,5,10,20])/100

# Iterate through each standard deviation
for std_dev in errors:
    
    # Initialize dictionaries for the current standard deviation
    valid_scores[f"std_{std_dev}"]={}
    test_scores[f"std_{std_dev}"]={}
    trains[f"std_{std_dev}"]={}
    valids[f"std_{std_dev}"]={}
    tests[f"std_{std_dev}"]={}
    
    # Iterate through whether or not to add noise to the training set
    for train_noise in [True,False]:
        
        # Initialize dictionaries for the current standard deviation and train noise flag
        valid_scores[f"std_{std_dev}"][f"train_noise_{train_noise}"]={}
        test_scores[f"std_{std_dev}"][f"train_noise_{train_noise}"]={}
        trains[f"std_{std_dev}"][f"train_noise_{train_noise}"]={}
        valids[f"std_{std_dev}"][f"train_noise_{train_noise}"]={}
        tests[f"std_{std_dev}"][f"train_noise_{train_noise}"]={}
        
        # Iterate through each fold of the cross-validation
        for fold in folds:

            # Split the data into training, validation, and testing sets based on the fold periods
            train_period = (df["time"]<folds[f"{fold}"]["valid_start"]) 
            valid_period = (df["time"]>=folds[f"{fold}"]["valid_start"]) & (df["time"]<folds[f"{fold}"]["test_start"])
            test_period = (df["time"]>=folds[f"{fold}"]["test_start"]) & (df["time"]<=folds[f"{fold}"]["test_end"])

            train = df[train_period ].copy()
            train = train[~pd.isnull(train[TARGET])]

            valid = df[valid_period].copy()
            valid  = valid[~pd.isnull(valid[TARGET])]

            test  = df[test_period].copy()
            test  = test[~pd.isnull(test[TARGET])]

            # Add noise to the testing set based on the current standard deviation
            test["temp"]*=np.random.normal(1,std_dev,len(test))
            test["humidity"]*=np.random.normal(1,std_dev,len(test))

            # Add noise to the training and validation sets if specified
            if train_noise==True:
                train["temp"]*=np.random.normal(1,std_dev,len(train))
                train["humidity"]*=np.random.normal(1,std_dev,len(train))

                valid["temp"]*=np.random.normal(1,std_dev,len(valid))
                valid["humidity"]*=np.random.normal(1,std_dev,len(valid))

            # Create LightGBM datasets for training and validation
            X_train  = train[feature_list].copy()
            X_valid  = valid[feature_list].copy()
            X_test   = test[feature_list].copy()

            y_train = (train[TARGET].values)
            y_val   = (valid[TARGET].values)
            y_test   = (test[TARGET].values)

            train_dataset = lgb.Dataset(X_train, y_train)
            val_dataset   = lgb.Dataset(X_valid, y_val)

            # Initialize the predictions for the validation and testing sets
            valid["preds"] = 0
            test["preds"] = 0

            # Train multiple models with different random seeds and average the predictions
            for i in range(0,Seed):
                print("Seed--",i)
                parameters["seed"]  = i
                model = lgb.train(params = parameters, 
                                  train_set = train_dataset, 
                                  valid_sets = [val_dataset], 
                                  feval = mape,
                                  early_stopping_rounds = 250,
                                  verbose_eval = 100,
                                  num_boost_round = iterations)

                valid["preds"] = valid["preds"] + model.predict(X_valid,num_iteration=model.best_iteration)
                test["preds"] = test["preds"] + model.predict(X_test,num_iteration=model.best_iteration)

            # Average the predictions across the multiple models
            valid["preds"] = valid["preds"]/Seed
            test["preds"] = test["preds"]/Seed

            # Calculate the mean absolute percentage error for the validation and testing sets
            valid["mape"] = 100*abs(valid[TARGET]-valid["preds"])/valid[TARGET]
            test["mape"] = 100*abs(test[TARGET]-test["preds"])/test[TARGET]

            # Store the mean absolute percentage error scores and the training, validation, and testing sets for the current fold and parameters
            valid_scores[f"std_{std_dev}"][f"train_noise_{train_noise}"][fold] =valid["mape"].mean()
            test_scores[f"std_{std_dev}"][f"train_noise_{train_noise}"][fold] = test["mape"].mean()
            trains[f"std_{std_dev}"][f"train_noise_{train_noise}"][fold]=train.copy()
            valids[f"std_{std_dev}"][f"train_noise_{train_noise}"][fold]=valid.copy()
            tests[f"std_{std_dev}"][f"train_noise_{train_noise}"][fold] =test.copy()
# Out:
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 980.659	valid_0's mape: 3.4484
# [200]	valid_0's l1: 934.105	valid_0's mape: 3.28576
# [300]	valid_0's l1: 914.627	valid_0's mape: 3.22182
# [400]	valid_0's l1: 905.645	valid_0's mape: 3.18761
# [500]	valid_0's l1: 894.373	valid_0's mape: 3.1432
# [600]	valid_0's l1: 892.776	valid_0's mape: 3.13513
# [700]	valid_0's l1: 892.186	valid_0's mape: 3.1321
# [800]	valid_0's l1: 887.856	valid_0's mape: 3.11343
# [900]	valid_0's l1: 889.126	valid_0's mape: 3.11684
# [1000]	valid_0's l1: 888.466	valid_0's mape: 3.11401
# Early stopping, best iteration is:
# [770]	valid_0's l1: 887.094	valid_0's mape: 3.11076
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1004.36	valid_0's mape: 3.53094
# [200]	valid_0's l1: 963.497	valid_0's mape: 3.39221
# [300]	valid_0's l1: 956.266	valid_0's mape: 3.36294
# [400]	valid_0's l1: 950.682	valid_0's mape: 3.33743
# [500]	valid_0's l1: 943.048	valid_0's mape: 3.3062
# [600]	valid_0's l1: 941.767	valid_0's mape: 3.29827
# [700]	valid_0's l1: 938.809	valid_0's mape: 3.28459
# [800]	valid_0's l1: 936.058	valid_0's mape: 3.27654
# [900]	valid_0's l1: 934.411	valid_0's mape: 3.26818
# [1000]	valid_0's l1: 934.063	valid_0's mape: 3.26284
# [1100]	valid_0's l1: 932.194	valid_0's mape: 3.2561
# [1200]	valid_0's l1: 932.537	valid_0's mape: 3.25757
# [1300]	valid_0's l1: 931.018	valid_0's mape: 3.25305
# [1400]	valid_0's l1: 930.456	valid_0's mape: 3.25053
# [1500]	valid_0's l1: 929.604	valid_0's mape: 3.24648
# [1600]	valid_0's l1: 930.702	valid_0's mape: 3.24905
# [1700]	valid_0's l1: 928.884	valid_0's mape: 3.24273
# [1800]	valid_0's l1: 929.526	valid_0's mape: 3.24477
# [1900]	valid_0's l1: 929.12	valid_0's mape: 3.24256
# [2000]	valid_0's l1: 927.936	valid_0's mape: 3.23835
# [2100]	valid_0's l1: 927.577	valid_0's mape: 3.236
# [2200]	valid_0's l1: 927.99	valid_0's mape: 3.23671
# [2300]	valid_0's l1: 927.85	valid_0's mape: 3.236
# Early stopping, best iteration is:
# [2086]	valid_0's l1: 927.116	valid_0's mape: 3.23428
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 961.561	valid_0's mape: 3.3879
# [200]	valid_0's l1: 914.282	valid_0's mape: 3.23242
# [300]	valid_0's l1: 905.133	valid_0's mape: 3.19523
# [400]	valid_0's l1: 906.063	valid_0's mape: 3.19572
# [500]	valid_0's l1: 904.859	valid_0's mape: 3.18986
# [600]	valid_0's l1: 901.56	valid_0's mape: 3.17588
# [700]	valid_0's l1: 897.676	valid_0's mape: 3.16204
# [800]	valid_0's l1: 897.955	valid_0's mape: 3.16206
# [900]	valid_0's l1: 896.049	valid_0's mape: 3.15537
# [1000]	valid_0's l1: 896.365	valid_0's mape: 3.15563
# [1100]	valid_0's l1: 899.831	valid_0's mape: 3.16757
# [1200]	valid_0's l1: 900.183	valid_0's mape: 3.16761
# Early stopping, best iteration is:
# [977]	valid_0's l1: 894.649	valid_0's mape: 3.14941
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 984.457	valid_0's mape: 3.45866
# [200]	valid_0's l1: 946.411	valid_0's mape: 3.32485
# [300]	valid_0's l1: 934.617	valid_0's mape: 3.28294
# [400]	valid_0's l1: 924.031	valid_0's mape: 3.24539
# [500]	valid_0's l1: 923.48	valid_0's mape: 3.23959
# [600]	valid_0's l1: 917.655	valid_0's mape: 3.21687
# [700]	valid_0's l1: 917.009	valid_0's mape: 3.21197
# [800]	valid_0's l1: 913.539	valid_0's mape: 3.19648
# [900]	valid_0's l1: 908.758	valid_0's mape: 3.17945
# [1000]	valid_0's l1: 910.3	valid_0's mape: 3.18273
# [1100]	valid_0's l1: 909.976	valid_0's mape: 3.18064
# Early stopping, best iteration is:
# [926]	valid_0's l1: 907.638	valid_0's mape: 3.17434
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 958.763	valid_0's mape: 3.37471
# [200]	valid_0's l1: 928.717	valid_0's mape: 3.2599
# [300]	valid_0's l1: 917.119	valid_0's mape: 3.218
# [400]	valid_0's l1: 911.552	valid_0's mape: 3.20181
# [500]	valid_0's l1: 906.61	valid_0's mape: 3.18517
# [600]	valid_0's l1: 907.398	valid_0's mape: 3.18483
# [700]	valid_0's l1: 909.119	valid_0's mape: 3.18556
# Early stopping, best iteration is:
# [515]	valid_0's l1: 906.251	valid_0's mape: 3.18456
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1031.4	valid_0's mape: 3.61708
# [200]	valid_0's l1: 1001.52	valid_0's mape: 3.50597
# [300]	valid_0's l1: 983.508	valid_0's mape: 3.44139
# [400]	valid_0's l1: 973.751	valid_0's mape: 3.4046
# [500]	valid_0's l1: 970.456	valid_0's mape: 3.39199
# [600]	valid_0's l1: 968.244	valid_0's mape: 3.38253
# [700]	valid_0's l1: 968.174	valid_0's mape: 3.38005
# [800]	valid_0's l1: 967.66	valid_0's mape: 3.37532
# [900]	valid_0's l1: 967.016	valid_0's mape: 3.37104
# [1000]	valid_0's l1: 965.394	valid_0's mape: 3.36342
# [1100]	valid_0's l1: 965.774	valid_0's mape: 3.36541
# [1200]	valid_0's l1: 966.716	valid_0's mape: 3.36631
# [1300]	valid_0's l1: 966.233	valid_0's mape: 3.36447
# Early stopping, best iteration is:
# [1088]	valid_0's l1: 964.163	valid_0's mape: 3.35955
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1009.31	valid_0's mape: 3.53799
# [200]	valid_0's l1: 989.114	valid_0's mape: 3.46178
# [300]	valid_0's l1: 975.83	valid_0's mape: 3.41316
# [400]	valid_0's l1: 967.164	valid_0's mape: 3.38124
# [500]	valid_0's l1: 960.726	valid_0's mape: 3.35707
# [600]	valid_0's l1: 961.637	valid_0's mape: 3.35824
# [700]	valid_0's l1: 958.685	valid_0's mape: 3.346
# [800]	valid_0's l1: 957.005	valid_0's mape: 3.33794
# [900]	valid_0's l1: 955.27	valid_0's mape: 3.33102
# [1000]	valid_0's l1: 954.34	valid_0's mape: 3.32583
# [1100]	valid_0's l1: 954.75	valid_0's mape: 3.32648
# [1200]	valid_0's l1: 951.677	valid_0's mape: 3.31401
# [1300]	valid_0's l1: 950.505	valid_0's mape: 3.30923
# [1400]	valid_0's l1: 949.298	valid_0's mape: 3.30358
# [1500]	valid_0's l1: 949.19	valid_0's mape: 3.30203
# [1600]	valid_0's l1: 948.332	valid_0's mape: 3.29864
# [1700]	valid_0's l1: 947.071	valid_0's mape: 3.29283
# [1800]	valid_0's l1: 945.207	valid_0's mape: 3.28731
# [1900]	valid_0's l1: 945.043	valid_0's mape: 3.28601
# [2000]	valid_0's l1: 945.212	valid_0's mape: 3.2864
# [2100]	valid_0's l1: 945.048	valid_0's mape: 3.28537
# [2200]	valid_0's l1: 943.621	valid_0's mape: 3.27959
# [2300]	valid_0's l1: 943.479	valid_0's mape: 3.27879
# [2400]	valid_0's l1: 942.852	valid_0's mape: 3.27526
# [2500]	valid_0's l1: 941.539	valid_0's mape: 3.27113
# [2600]	valid_0's l1: 942.152	valid_0's mape: 3.27273
# [2700]	valid_0's l1: 943.853	valid_0's mape: 3.27886
# [2800]	valid_0's l1: 944.058	valid_0's mape: 3.2788
# Early stopping, best iteration is:
# [2576]	valid_0's l1: 941.177	valid_0's mape: 3.26935
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1039.84	valid_0's mape: 3.65346
# [200]	valid_0's l1: 1023.72	valid_0's mape: 3.58484
# [300]	valid_0's l1: 1009.64	valid_0's mape: 3.53446
# [400]	valid_0's l1: 1002.77	valid_0's mape: 3.5053
# [500]	valid_0's l1: 1000.15	valid_0's mape: 3.49481
# [600]	valid_0's l1: 994.257	valid_0's mape: 3.46941
# [700]	valid_0's l1: 988.283	valid_0's mape: 3.44728
# [800]	valid_0's l1: 988.021	valid_0's mape: 3.44419
# [900]	valid_0's l1: 989.917	valid_0's mape: 3.45
# [1000]	valid_0's l1: 987.572	valid_0's mape: 3.44231
# [1100]	valid_0's l1: 985.217	valid_0's mape: 3.43279
# [1200]	valid_0's l1: 985.127	valid_0's mape: 3.43152
# [1300]	valid_0's l1: 984.478	valid_0's mape: 3.42835
# [1400]	valid_0's l1: 985.138	valid_0's mape: 3.43027
# [1500]	valid_0's l1: 985.604	valid_0's mape: 3.43162
# Early stopping, best iteration is:
# [1254]	valid_0's l1: 983.786	valid_0's mape: 3.42571
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1020.49	valid_0's mape: 3.58254
# [200]	valid_0's l1: 991.46	valid_0's mape: 3.47452
# [300]	valid_0's l1: 981.999	valid_0's mape: 3.43815
# [400]	valid_0's l1: 978.921	valid_0's mape: 3.42625
# [500]	valid_0's l1: 979.032	valid_0's mape: 3.42377
# [600]	valid_0's l1: 979.424	valid_0's mape: 3.42363
# [700]	valid_0's l1: 979.299	valid_0's mape: 3.4204
# [800]	valid_0's l1: 979.338	valid_0's mape: 3.41996
# Early stopping, best iteration is:
# [554]	valid_0's l1: 976.553	valid_0's mape: 3.41352
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1043.41	valid_0's mape: 3.66248
# [200]	valid_0's l1: 1019.08	valid_0's mape: 3.57515
# [300]	valid_0's l1: 1005.34	valid_0's mape: 3.52447
# [400]	valid_0's l1: 1001.76	valid_0's mape: 3.51221
# [500]	valid_0's l1: 991.622	valid_0's mape: 3.47544
# [600]	valid_0's l1: 984.027	valid_0's mape: 3.44632
# [700]	valid_0's l1: 982.034	valid_0's mape: 3.43724
# [800]	valid_0's l1: 979.895	valid_0's mape: 3.42889
# [900]	valid_0's l1: 975.744	valid_0's mape: 3.4131
# [1000]	valid_0's l1: 973.766	valid_0's mape: 3.40567
# [1100]	valid_0's l1: 973.352	valid_0's mape: 3.40387
# [1200]	valid_0's l1: 972.417	valid_0's mape: 3.3998
# [1300]	valid_0's l1: 973.409	valid_0's mape: 3.40288
# [1400]	valid_0's l1: 971.977	valid_0's mape: 3.39525
# [1500]	valid_0's l1: 972.559	valid_0's mape: 3.3961
# Early stopping, best iteration is:
# [1307]	valid_0's l1: 970.922	valid_0's mape: 3.39396
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 970.787	valid_0's mape: 3.38378
# [200]	valid_0's l1: 956.012	valid_0's mape: 3.33166
# [300]	valid_0's l1: 936.865	valid_0's mape: 3.26579
# [400]	valid_0's l1: 934.685	valid_0's mape: 3.25726
# [500]	valid_0's l1: 930.76	valid_0's mape: 3.24346
# [600]	valid_0's l1: 931.15	valid_0's mape: 3.24304
# [700]	valid_0's l1: 931.244	valid_0's mape: 3.2429
# [800]	valid_0's l1: 932.549	valid_0's mape: 3.24794
# Early stopping, best iteration is:
# [635]	valid_0's l1: 929.454	valid_0's mape: 3.23693
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 977.807	valid_0's mape: 3.40078
# [200]	valid_0's l1: 975.967	valid_0's mape: 3.38594
# [300]	valid_0's l1: 967.2	valid_0's mape: 3.35625
# [400]	valid_0's l1: 962.745	valid_0's mape: 3.34064
# [500]	valid_0's l1: 954.947	valid_0's mape: 3.31781
# [600]	valid_0's l1: 949.318	valid_0's mape: 3.30066
# [700]	valid_0's l1: 947.375	valid_0's mape: 3.29108
# [800]	valid_0's l1: 949.306	valid_0's mape: 3.29811
# [900]	valid_0's l1: 949.432	valid_0's mape: 3.2971
# [1000]	valid_0's l1: 947.993	valid_0's mape: 3.29256
# [1100]	valid_0's l1: 946.374	valid_0's mape: 3.28693
# Early stopping, best iteration is:
# [926]	valid_0's l1: 945.135	valid_0's mape: 3.28347
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 940.341	valid_0's mape: 3.27738
# [200]	valid_0's l1: 934.577	valid_0's mape: 3.26198
# [300]	valid_0's l1: 921.483	valid_0's mape: 3.21935
# [400]	valid_0's l1: 919.19	valid_0's mape: 3.20731
# [500]	valid_0's l1: 914.656	valid_0's mape: 3.19144
# [600]	valid_0's l1: 912.293	valid_0's mape: 3.18283
# [700]	valid_0's l1: 909.331	valid_0's mape: 3.17379
# [800]	valid_0's l1: 910.562	valid_0's mape: 3.17906
# [900]	valid_0's l1: 910.978	valid_0's mape: 3.18102
# Early stopping, best iteration is:
# [672]	valid_0's l1: 908.756	valid_0's mape: 3.17141
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 975.821	valid_0's mape: 3.39811
# [200]	valid_0's l1: 955.429	valid_0's mape: 3.32683
# [300]	valid_0's l1: 949.269	valid_0's mape: 3.3049
# [400]	valid_0's l1: 941.658	valid_0's mape: 3.27572
# [500]	valid_0's l1: 937.527	valid_0's mape: 3.26051
# [600]	valid_0's l1: 933.647	valid_0's mape: 3.24401
# [700]	valid_0's l1: 935.535	valid_0's mape: 3.25014
# [800]	valid_0's l1: 933.409	valid_0's mape: 3.24094
# Early stopping, best iteration is:
# [633]	valid_0's l1: 932.221	valid_0's mape: 3.2384
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 998.386	valid_0's mape: 3.47429
# [200]	valid_0's l1: 979.69	valid_0's mape: 3.40085
# [300]	valid_0's l1: 969.544	valid_0's mape: 3.36369
# [400]	valid_0's l1: 964.934	valid_0's mape: 3.34868
# [500]	valid_0's l1: 959.967	valid_0's mape: 3.33172
# [600]	valid_0's l1: 951.728	valid_0's mape: 3.30477
# [700]	valid_0's l1: 949.738	valid_0's mape: 3.30314
# [800]	valid_0's l1: 947.332	valid_0's mape: 3.29411
# [900]	valid_0's l1: 946.195	valid_0's mape: 3.28904
# [1000]	valid_0's l1: 945.035	valid_0's mape: 3.28464
# [1100]	valid_0's l1: 941.393	valid_0's mape: 3.27047
# [1200]	valid_0's l1: 943.986	valid_0's mape: 3.2794
# [1300]	valid_0's l1: 944.376	valid_0's mape: 3.2805
# Early stopping, best iteration is:
# [1119]	valid_0's l1: 940.848	valid_0's mape: 3.26866
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 898.376	valid_0's mape: 3.11629
# [200]	valid_0's l1: 902.196	valid_0's mape: 3.12522
# [300]	valid_0's l1: 891.126	valid_0's mape: 3.0848
# [400]	valid_0's l1: 892.305	valid_0's mape: 3.09086
# [500]	valid_0's l1: 898.799	valid_0's mape: 3.1129
# Early stopping, best iteration is:
# [323]	valid_0's l1: 890.436	valid_0's mape: 3.0823
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 910.585	valid_0's mape: 3.15708
# [200]	valid_0's l1: 884.827	valid_0's mape: 3.06159
# [300]	valid_0's l1: 879.188	valid_0's mape: 3.04378
# [400]	valid_0's l1: 876.072	valid_0's mape: 3.03087
# [500]	valid_0's l1: 874.277	valid_0's mape: 3.02324
# [600]	valid_0's l1: 876.087	valid_0's mape: 3.02876
# [700]	valid_0's l1: 876.542	valid_0's mape: 3.0283
# Early stopping, best iteration is:
# [523]	valid_0's l1: 873.202	valid_0's mape: 3.0196
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 948.863	valid_0's mape: 3.27691
# [200]	valid_0's l1: 932.299	valid_0's mape: 3.21503
# [300]	valid_0's l1: 931.739	valid_0's mape: 3.20826
# [400]	valid_0's l1: 926.949	valid_0's mape: 3.19271
# [500]	valid_0's l1: 928.355	valid_0's mape: 3.19346
# [600]	valid_0's l1: 931.345	valid_0's mape: 3.20265
# Early stopping, best iteration is:
# [425]	valid_0's l1: 925.458	valid_0's mape: 3.18624
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 910.078	valid_0's mape: 3.15603
# [200]	valid_0's l1: 894.159	valid_0's mape: 3.09514
# [300]	valid_0's l1: 897.33	valid_0's mape: 3.10445
# [400]	valid_0's l1: 896.392	valid_0's mape: 3.102
# Early stopping, best iteration is:
# [242]	valid_0's l1: 892.356	valid_0's mape: 3.08483
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 932.3	valid_0's mape: 3.22928
# [200]	valid_0's l1: 915.121	valid_0's mape: 3.16092
# [300]	valid_0's l1: 912.851	valid_0's mape: 3.15281
# [400]	valid_0's l1: 910.609	valid_0's mape: 3.14431
# [500]	valid_0's l1: 906.656	valid_0's mape: 3.12949
# [600]	valid_0's l1: 905.658	valid_0's mape: 3.12541
# [700]	valid_0's l1: 905.383	valid_0's mape: 3.12356
# [800]	valid_0's l1: 903.037	valid_0's mape: 3.11531
# [900]	valid_0's l1: 902.533	valid_0's mape: 3.11305
# [1000]	valid_0's l1: 903.736	valid_0's mape: 3.11623
# [1100]	valid_0's l1: 904.639	valid_0's mape: 3.11832
# Early stopping, best iteration is:
# [855]	valid_0's l1: 900.656	valid_0's mape: 3.10679
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1030.81	valid_0's mape: 3.68398
# [200]	valid_0's l1: 1035.97	valid_0's mape: 3.69968
# [300]	valid_0's l1: 1026.08	valid_0's mape: 3.66197
# Early stopping, best iteration is:
# [148]	valid_0's l1: 1019.74	valid_0's mape: 3.63724
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1022.41	valid_0's mape: 3.66416
# [200]	valid_0's l1: 998.613	valid_0's mape: 3.56651
# [300]	valid_0's l1: 996.818	valid_0's mape: 3.55734
# [400]	valid_0's l1: 993.984	valid_0's mape: 3.54376
# [500]	valid_0's l1: 994.111	valid_0's mape: 3.54227
# [600]	valid_0's l1: 990.18	valid_0's mape: 3.52694
# [700]	valid_0's l1: 995.575	valid_0's mape: 3.54691
# [800]	valid_0's l1: 994.634	valid_0's mape: 3.54136
# Early stopping, best iteration is:
# [602]	valid_0's l1: 988.453	valid_0's mape: 3.52091
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1016.58	valid_0's mape: 3.615
# [200]	valid_0's l1: 1027.72	valid_0's mape: 3.6476
# [300]	valid_0's l1: 1023.45	valid_0's mape: 3.62543
# Early stopping, best iteration is:
# [118]	valid_0's l1: 1011.93	valid_0's mape: 3.59827
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1072.69	valid_0's mape: 3.80375
# [200]	valid_0's l1: 1073.18	valid_0's mape: 3.81162
# [300]	valid_0's l1: 1065.37	valid_0's mape: 3.77966
# Early stopping, best iteration is:
# [66]	valid_0's l1: 1049.95	valid_0's mape: 3.72737
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1080.34	valid_0's mape: 3.82312
# [200]	valid_0's l1: 1064.66	valid_0's mape: 3.76205
# [300]	valid_0's l1: 1079.32	valid_0's mape: 3.8192
# Early stopping, best iteration is:
# [56]	valid_0's l1: 1055.34	valid_0's mape: 3.74502
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 747.144	valid_0's mape: 2.68408
# [200]	valid_0's l1: 719.138	valid_0's mape: 2.58149
# [300]	valid_0's l1: 709.917	valid_0's mape: 2.54273
# [400]	valid_0's l1: 708.22	valid_0's mape: 2.53495
# [500]	valid_0's l1: 704.394	valid_0's mape: 2.52017
# [600]	valid_0's l1: 700.742	valid_0's mape: 2.50731
# [700]	valid_0's l1: 699.347	valid_0's mape: 2.50127
# [800]	valid_0's l1: 698.499	valid_0's mape: 2.49699
# [900]	valid_0's l1: 693.692	valid_0's mape: 2.47931
# [1000]	valid_0's l1: 694.573	valid_0's mape: 2.48118
# [1100]	valid_0's l1: 692.866	valid_0's mape: 2.47458
# [1200]	valid_0's l1: 691.681	valid_0's mape: 2.46951
# [1300]	valid_0's l1: 691.763	valid_0's mape: 2.46988
# [1400]	valid_0's l1: 692.61	valid_0's mape: 2.4721
# Early stopping, best iteration is:
# [1241]	valid_0's l1: 690.863	valid_0's mape: 2.46655
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 769.368	valid_0's mape: 2.74162
# [200]	valid_0's l1: 728.516	valid_0's mape: 2.5906
# [300]	valid_0's l1: 711.081	valid_0's mape: 2.52668
# [400]	valid_0's l1: 704.756	valid_0's mape: 2.50292
# [500]	valid_0's l1: 699.407	valid_0's mape: 2.48291
# [600]	valid_0's l1: 698.224	valid_0's mape: 2.47846
# [700]	valid_0's l1: 695.487	valid_0's mape: 2.46913
# [800]	valid_0's l1: 693.888	valid_0's mape: 2.46387
# [900]	valid_0's l1: 694.368	valid_0's mape: 2.46492
# [1000]	valid_0's l1: 694.145	valid_0's mape: 2.46453
# [1100]	valid_0's l1: 692.889	valid_0's mape: 2.46042
# [1200]	valid_0's l1: 691.835	valid_0's mape: 2.45627
# [1300]	valid_0's l1: 690.944	valid_0's mape: 2.45309
# [1400]	valid_0's l1: 690.872	valid_0's mape: 2.45309
# [1500]	valid_0's l1: 689.834	valid_0's mape: 2.45011
# [1600]	valid_0's l1: 689.591	valid_0's mape: 2.44917
# [1700]	valid_0's l1: 689.646	valid_0's mape: 2.44951
# [1800]	valid_0's l1: 689.551	valid_0's mape: 2.44889
# [1900]	valid_0's l1: 688.679	valid_0's mape: 2.44571
# [2000]	valid_0's l1: 687.289	valid_0's mape: 2.43968
# [2100]	valid_0's l1: 687.213	valid_0's mape: 2.43928
# [2200]	valid_0's l1: 685.958	valid_0's mape: 2.43375
# [2300]	valid_0's l1: 684.809	valid_0's mape: 2.42983
# [2400]	valid_0's l1: 685.882	valid_0's mape: 2.43382
# [2500]	valid_0's l1: 684.691	valid_0's mape: 2.42886
# [2600]	valid_0's l1: 684.891	valid_0's mape: 2.4293
# Early stopping, best iteration is:
# [2431]	valid_0's l1: 684.285	valid_0's mape: 2.42697
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 758.021	valid_0's mape: 2.70334
# [200]	valid_0's l1: 723.598	valid_0's mape: 2.58127
# [300]	valid_0's l1: 717.259	valid_0's mape: 2.55776
# [400]	valid_0's l1: 713.912	valid_0's mape: 2.54546
# [500]	valid_0's l1: 708.908	valid_0's mape: 2.53001
# [600]	valid_0's l1: 707.52	valid_0's mape: 2.52582
# [700]	valid_0's l1: 703.663	valid_0's mape: 2.51205
# [800]	valid_0's l1: 699.939	valid_0's mape: 2.49934
# [900]	valid_0's l1: 697.76	valid_0's mape: 2.49173
# [1000]	valid_0's l1: 697.094	valid_0's mape: 2.48983
# [1100]	valid_0's l1: 698.004	valid_0's mape: 2.49303
# [1200]	valid_0's l1: 697.999	valid_0's mape: 2.49238
# [1300]	valid_0's l1: 698.249	valid_0's mape: 2.49379
# Early stopping, best iteration is:
# [1071]	valid_0's l1: 696.419	valid_0's mape: 2.48742
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 786.808	valid_0's mape: 2.7971
# [200]	valid_0's l1: 734.655	valid_0's mape: 2.61481
# [300]	valid_0's l1: 719.143	valid_0's mape: 2.56143
# [400]	valid_0's l1: 713.184	valid_0's mape: 2.54168
# [500]	valid_0's l1: 708.798	valid_0's mape: 2.52623
# [600]	valid_0's l1: 710.627	valid_0's mape: 2.53311
# [700]	valid_0's l1: 708.371	valid_0's mape: 2.52337
# [800]	valid_0's l1: 703.134	valid_0's mape: 2.50412
# [900]	valid_0's l1: 703.457	valid_0's mape: 2.50575
# [1000]	valid_0's l1: 702.931	valid_0's mape: 2.50349
# Early stopping, best iteration is:
# [818]	valid_0's l1: 702.352	valid_0's mape: 2.50191
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 763.929	valid_0's mape: 2.72602
# [200]	valid_0's l1: 733.191	valid_0's mape: 2.61951
# [300]	valid_0's l1: 718.371	valid_0's mape: 2.56289
# [400]	valid_0's l1: 714.431	valid_0's mape: 2.55041
# [500]	valid_0's l1: 708.102	valid_0's mape: 2.52829
# [600]	valid_0's l1: 703.282	valid_0's mape: 2.51003
# [700]	valid_0's l1: 698.924	valid_0's mape: 2.49059
# [800]	valid_0's l1: 696.962	valid_0's mape: 2.48316
# [900]	valid_0's l1: 696.889	valid_0's mape: 2.482
# [1000]	valid_0's l1: 695.795	valid_0's mape: 2.47666
# [1100]	valid_0's l1: 693.902	valid_0's mape: 2.46979
# [1200]	valid_0's l1: 691.013	valid_0's mape: 2.45841
# [1300]	valid_0's l1: 691.195	valid_0's mape: 2.45936
# [1400]	valid_0's l1: 692.151	valid_0's mape: 2.46351
# Early stopping, best iteration is:
# [1239]	valid_0's l1: 690.248	valid_0's mape: 2.45598
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 871.12	valid_0's mape: 3.10911
# [200]	valid_0's l1: 824.72	valid_0's mape: 2.93256
# [300]	valid_0's l1: 814.963	valid_0's mape: 2.89813
# [400]	valid_0's l1: 808.671	valid_0's mape: 2.87279
# [500]	valid_0's l1: 805.158	valid_0's mape: 2.86102
# [600]	valid_0's l1: 800.489	valid_0's mape: 2.8457
# [700]	valid_0's l1: 796.747	valid_0's mape: 2.83199
# [800]	valid_0's l1: 795.33	valid_0's mape: 2.8278
# [900]	valid_0's l1: 793.76	valid_0's mape: 2.82308
# [1000]	valid_0's l1: 793.165	valid_0's mape: 2.81985
# [1100]	valid_0's l1: 792.883	valid_0's mape: 2.81892
# [1200]	valid_0's l1: 792.095	valid_0's mape: 2.81551
# [1300]	valid_0's l1: 791.572	valid_0's mape: 2.81624
# [1400]	valid_0's l1: 790.616	valid_0's mape: 2.81195
# [1500]	valid_0's l1: 790.645	valid_0's mape: 2.81203
# [1600]	valid_0's l1: 790.752	valid_0's mape: 2.81268
# [1700]	valid_0's l1: 789.69	valid_0's mape: 2.80939
# [1800]	valid_0's l1: 789.659	valid_0's mape: 2.80915
# [1900]	valid_0's l1: 790.363	valid_0's mape: 2.81156
# Early stopping, best iteration is:
# [1716]	valid_0's l1: 789.272	valid_0's mape: 2.80785
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 849.747	valid_0's mape: 3.03018
# [200]	valid_0's l1: 809.165	valid_0's mape: 2.87872
# [300]	valid_0's l1: 802.651	valid_0's mape: 2.85063
# [400]	valid_0's l1: 793.58	valid_0's mape: 2.81833
# [500]	valid_0's l1: 792.889	valid_0's mape: 2.81744
# [600]	valid_0's l1: 790.832	valid_0's mape: 2.80887
# [700]	valid_0's l1: 789.27	valid_0's mape: 2.80354
# [800]	valid_0's l1: 789.089	valid_0's mape: 2.80276
# [900]	valid_0's l1: 789.96	valid_0's mape: 2.80678
# [1000]	valid_0's l1: 788.449	valid_0's mape: 2.80117
# [1100]	valid_0's l1: 788.153	valid_0's mape: 2.79975
# [1200]	valid_0's l1: 786.456	valid_0's mape: 2.79304
# [1300]	valid_0's l1: 783.954	valid_0's mape: 2.78424
# [1400]	valid_0's l1: 782.372	valid_0's mape: 2.77811
# [1500]	valid_0's l1: 781.569	valid_0's mape: 2.77545
# [1600]	valid_0's l1: 781.716	valid_0's mape: 2.77559
# [1700]	valid_0's l1: 782.231	valid_0's mape: 2.77655
# [1800]	valid_0's l1: 783.743	valid_0's mape: 2.78205
# Early stopping, best iteration is:
# [1628]	valid_0's l1: 780.953	valid_0's mape: 2.77265
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 840.046	valid_0's mape: 2.99782
# [200]	valid_0's l1: 816.783	valid_0's mape: 2.90805
# [300]	valid_0's l1: 816.42	valid_0's mape: 2.9074
# [400]	valid_0's l1: 811.882	valid_0's mape: 2.89195
# [500]	valid_0's l1: 806.969	valid_0's mape: 2.87469
# [600]	valid_0's l1: 805.182	valid_0's mape: 2.86813
# [700]	valid_0's l1: 804.253	valid_0's mape: 2.86612
# [800]	valid_0's l1: 802.229	valid_0's mape: 2.85927
# [900]	valid_0's l1: 803.053	valid_0's mape: 2.86189
# [1000]	valid_0's l1: 801.319	valid_0's mape: 2.85384
# [1100]	valid_0's l1: 802.363	valid_0's mape: 2.85814
# [1200]	valid_0's l1: 801.519	valid_0's mape: 2.85476
# Early stopping, best iteration is:
# [1017]	valid_0's l1: 800.768	valid_0's mape: 2.85166
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 867.798	valid_0's mape: 3.08983
# [200]	valid_0's l1: 834.263	valid_0's mape: 2.9647
# [300]	valid_0's l1: 825.71	valid_0's mape: 2.93488
# [400]	valid_0's l1: 817.86	valid_0's mape: 2.90701
# [500]	valid_0's l1: 819.332	valid_0's mape: 2.91096
# [600]	valid_0's l1: 816.689	valid_0's mape: 2.90041
# [700]	valid_0's l1: 814.004	valid_0's mape: 2.89278
# [800]	valid_0's l1: 814.897	valid_0's mape: 2.89698
# [900]	valid_0's l1: 812.976	valid_0's mape: 2.88823
# Early stopping, best iteration is:
# [652]	valid_0's l1: 811.615	valid_0's mape: 2.88402
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 856.641	valid_0's mape: 3.0413
# [200]	valid_0's l1: 842.37	valid_0's mape: 2.9844
# [300]	valid_0's l1: 839.379	valid_0's mape: 2.96928
# [400]	valid_0's l1: 836.877	valid_0's mape: 2.96447
# [500]	valid_0's l1: 838.589	valid_0's mape: 2.97177
# Early stopping, best iteration is:
# [323]	valid_0's l1: 834.621	valid_0's mape: 2.95551
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 774.263	valid_0's mape: 2.71554
# [200]	valid_0's l1: 733.366	valid_0's mape: 2.57197
# [300]	valid_0's l1: 729.823	valid_0's mape: 2.55538
# [400]	valid_0's l1: 725.144	valid_0's mape: 2.53606
# [500]	valid_0's l1: 725.602	valid_0's mape: 2.53755
# [600]	valid_0's l1: 722.274	valid_0's mape: 2.52575
# [700]	valid_0's l1: 723.488	valid_0's mape: 2.52959
# Early stopping, best iteration is:
# [451]	valid_0's l1: 721.048	valid_0's mape: 2.52126
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 764.671	valid_0's mape: 2.67012
# [200]	valid_0's l1: 742.69	valid_0's mape: 2.59089
# [300]	valid_0's l1: 733.225	valid_0's mape: 2.55861
# [400]	valid_0's l1: 729.835	valid_0's mape: 2.54735
# [500]	valid_0's l1: 726.776	valid_0's mape: 2.53545
# [600]	valid_0's l1: 724.232	valid_0's mape: 2.52579
# [700]	valid_0's l1: 725.599	valid_0's mape: 2.53153
# [800]	valid_0's l1: 726.925	valid_0's mape: 2.53706
# Early stopping, best iteration is:
# [610]	valid_0's l1: 723.424	valid_0's mape: 2.52349
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 781.243	valid_0's mape: 2.73535
# [200]	valid_0's l1: 759.318	valid_0's mape: 2.66638
# [300]	valid_0's l1: 753.36	valid_0's mape: 2.6439
# [400]	valid_0's l1: 745.276	valid_0's mape: 2.61928
# [500]	valid_0's l1: 747.403	valid_0's mape: 2.63288
# [600]	valid_0's l1: 747.804	valid_0's mape: 2.63276
# Early stopping, best iteration is:
# [438]	valid_0's l1: 740.004	valid_0's mape: 2.6054
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 778.494	valid_0's mape: 2.722
# [200]	valid_0's l1: 756.146	valid_0's mape: 2.64178
# [300]	valid_0's l1: 749.028	valid_0's mape: 2.61888
# [400]	valid_0's l1: 745.501	valid_0's mape: 2.6059
# [500]	valid_0's l1: 743.348	valid_0's mape: 2.59812
# [600]	valid_0's l1: 744.077	valid_0's mape: 2.6005
# [700]	valid_0's l1: 742.997	valid_0's mape: 2.5973
# [800]	valid_0's l1: 741.835	valid_0's mape: 2.59335
# [900]	valid_0's l1: 741.144	valid_0's mape: 2.59041
# [1000]	valid_0's l1: 736.692	valid_0's mape: 2.57964
# [1100]	valid_0's l1: 736.736	valid_0's mape: 2.58006
# [1200]	valid_0's l1: 735.959	valid_0's mape: 2.57723
# [1300]	valid_0's l1: 737.518	valid_0's mape: 2.58132
# [1400]	valid_0's l1: 737.258	valid_0's mape: 2.58002
# Early stopping, best iteration is:
# [1182]	valid_0's l1: 735.37	valid_0's mape: 2.57549
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 796.402	valid_0's mape: 2.78623
# [200]	valid_0's l1: 765.509	valid_0's mape: 2.67807
# [300]	valid_0's l1: 761.987	valid_0's mape: 2.65818
# [400]	valid_0's l1: 755.499	valid_0's mape: 2.63564
# [500]	valid_0's l1: 753.988	valid_0's mape: 2.63032
# [600]	valid_0's l1: 755.38	valid_0's mape: 2.63334
# [700]	valid_0's l1: 756.968	valid_0's mape: 2.63763
# [800]	valid_0's l1: 753.256	valid_0's mape: 2.62362
# Early stopping, best iteration is:
# [558]	valid_0's l1: 751.351	valid_0's mape: 2.62092
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 788.401	valid_0's mape: 2.75847
# [200]	valid_0's l1: 781.154	valid_0's mape: 2.72481
# [300]	valid_0's l1: 767.363	valid_0's mape: 2.67278
# [400]	valid_0's l1: 764.533	valid_0's mape: 2.65912
# [500]	valid_0's l1: 763.205	valid_0's mape: 2.65323
# [600]	valid_0's l1: 762.825	valid_0's mape: 2.64925
# [700]	valid_0's l1: 761.784	valid_0's mape: 2.64108
# [800]	valid_0's l1: 761.154	valid_0's mape: 2.63719
# [900]	valid_0's l1: 760.201	valid_0's mape: 2.63449
# [1000]	valid_0's l1: 762.806	valid_0's mape: 2.64278
# Early stopping, best iteration is:
# [778]	valid_0's l1: 758.304	valid_0's mape: 2.62674
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 743.745	valid_0's mape: 2.58179
# [200]	valid_0's l1: 723.547	valid_0's mape: 2.50903
# [300]	valid_0's l1: 718.976	valid_0's mape: 2.4936
# [400]	valid_0's l1: 711.715	valid_0's mape: 2.46699
# [500]	valid_0's l1: 714.253	valid_0's mape: 2.47436
# [600]	valid_0's l1: 715.333	valid_0's mape: 2.47767
# [700]	valid_0's l1: 716.42	valid_0's mape: 2.48121
# Early stopping, best iteration is:
# [496]	valid_0's l1: 710.558	valid_0's mape: 2.46218
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 785.844	valid_0's mape: 2.72329
# [200]	valid_0's l1: 757.607	valid_0's mape: 2.61978
# [300]	valid_0's l1: 747.017	valid_0's mape: 2.57675
# [400]	valid_0's l1: 742.257	valid_0's mape: 2.55922
# [500]	valid_0's l1: 741.621	valid_0's mape: 2.56003
# [600]	valid_0's l1: 741.96	valid_0's mape: 2.56276
# [700]	valid_0's l1: 738.881	valid_0's mape: 2.55293
# [800]	valid_0's l1: 738.132	valid_0's mape: 2.55004
# [900]	valid_0's l1: 735.073	valid_0's mape: 2.539
# [1000]	valid_0's l1: 735.881	valid_0's mape: 2.54173
# [1100]	valid_0's l1: 734.323	valid_0's mape: 2.53665
# [1200]	valid_0's l1: 737.692	valid_0's mape: 2.54863
# [1300]	valid_0's l1: 735.92	valid_0's mape: 2.54358
# Early stopping, best iteration is:
# [1111]	valid_0's l1: 734.091	valid_0's mape: 2.53589
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 781.818	valid_0's mape: 2.70985
# [200]	valid_0's l1: 770.311	valid_0's mape: 2.65812
# [300]	valid_0's l1: 768.29	valid_0's mape: 2.64528
# [400]	valid_0's l1: 760.533	valid_0's mape: 2.61669
# [500]	valid_0's l1: 757.435	valid_0's mape: 2.60401
# [600]	valid_0's l1: 758.415	valid_0's mape: 2.60671
# [700]	valid_0's l1: 759.537	valid_0's mape: 2.60894
# Early stopping, best iteration is:
# [535]	valid_0's l1: 756.824	valid_0's mape: 2.6023
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 761.316	valid_0's mape: 2.6501
# [200]	valid_0's l1: 737.528	valid_0's mape: 2.56311
# [300]	valid_0's l1: 735.41	valid_0's mape: 2.55087
# [400]	valid_0's l1: 731.519	valid_0's mape: 2.53726
# [500]	valid_0's l1: 731.364	valid_0's mape: 2.53437
# [600]	valid_0's l1: 730.871	valid_0's mape: 2.53324
# [700]	valid_0's l1: 733.372	valid_0's mape: 2.54198
# [800]	valid_0's l1: 732.907	valid_0's mape: 2.53827
# Early stopping, best iteration is:
# [558]	valid_0's l1: 729.415	valid_0's mape: 2.52839
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 917.001	valid_0's mape: 3.28586
# [200]	valid_0's l1: 927.018	valid_0's mape: 3.31862
# [300]	valid_0's l1: 933.991	valid_0's mape: 3.34255
# Early stopping, best iteration is:
# [90]	valid_0's l1: 901.763	valid_0's mape: 3.23053
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 894.749	valid_0's mape: 3.21685
# [200]	valid_0's l1: 901.987	valid_0's mape: 3.23776
# [300]	valid_0's l1: 928.071	valid_0's mape: 3.32525
# Early stopping, best iteration is:
# [99]	valid_0's l1: 894.056	valid_0's mape: 3.21475
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1029.41	valid_0's mape: 3.69765
# [200]	valid_0's l1: 1030.35	valid_0's mape: 3.68976
# [300]	valid_0's l1: 1049.89	valid_0's mape: 3.75385
# Early stopping, best iteration is:
# [54]	valid_0's l1: 969.888	valid_0's mape: 3.48247
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 933.1	valid_0's mape: 3.36481
# [200]	valid_0's l1: 928.123	valid_0's mape: 3.34038
# [300]	valid_0's l1: 922.464	valid_0's mape: 3.31745
# [400]	valid_0's l1: 942.385	valid_0's mape: 3.39025
# [500]	valid_0's l1: 939.097	valid_0's mape: 3.37471
# Early stopping, best iteration is:
# [302]	valid_0's l1: 920.939	valid_0's mape: 3.31198
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 932.255	valid_0's mape: 3.34101
# [200]	valid_0's l1: 980.82	valid_0's mape: 3.52102
# [300]	valid_0's l1: 989.295	valid_0's mape: 3.54821
# Early stopping, best iteration is:
# [67]	valid_0's l1: 906.85	valid_0's mape: 3.24811
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1173.09	valid_0's mape: 4.06719
# [200]	valid_0's l1: 1139.03	valid_0's mape: 3.94271
# [300]	valid_0's l1: 1134.8	valid_0's mape: 3.91859
# [400]	valid_0's l1: 1133.64	valid_0's mape: 3.9047
# [500]	valid_0's l1: 1127.46	valid_0's mape: 3.88376
# [600]	valid_0's l1: 1123.85	valid_0's mape: 3.86816
# [700]	valid_0's l1: 1121.97	valid_0's mape: 3.86146
# [800]	valid_0's l1: 1120.88	valid_0's mape: 3.85593
# [900]	valid_0's l1: 1119.08	valid_0's mape: 3.84892
# [1000]	valid_0's l1: 1119.4	valid_0's mape: 3.84819
# [1100]	valid_0's l1: 1114.97	valid_0's mape: 3.82925
# [1200]	valid_0's l1: 1119.26	valid_0's mape: 3.83897
# Early stopping, best iteration is:
# [1035]	valid_0's l1: 1114.33	valid_0's mape: 3.82819
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1151.47	valid_0's mape: 4.00948
# [200]	valid_0's l1: 1110.17	valid_0's mape: 3.87235
# [300]	valid_0's l1: 1103.81	valid_0's mape: 3.83645
# [400]	valid_0's l1: 1103.73	valid_0's mape: 3.83246
# [500]	valid_0's l1: 1099.03	valid_0's mape: 3.81153
# [600]	valid_0's l1: 1096.67	valid_0's mape: 3.79939
# [700]	valid_0's l1: 1099.35	valid_0's mape: 3.80513
# [800]	valid_0's l1: 1098.96	valid_0's mape: 3.80204
# Early stopping, best iteration is:
# [562]	valid_0's l1: 1095.88	valid_0's mape: 3.79763
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1115.28	valid_0's mape: 3.87502
# [200]	valid_0's l1: 1076.03	valid_0's mape: 3.73142
# [300]	valid_0's l1: 1063.67	valid_0's mape: 3.6866
# [400]	valid_0's l1: 1063.51	valid_0's mape: 3.68241
# [500]	valid_0's l1: 1062.66	valid_0's mape: 3.67233
# [600]	valid_0's l1: 1065.8	valid_0's mape: 3.67957
# Early stopping, best iteration is:
# [376]	valid_0's l1: 1060.49	valid_0's mape: 3.67361
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1138.6	valid_0's mape: 3.9395
# [200]	valid_0's l1: 1102.4	valid_0's mape: 3.80643
# [300]	valid_0's l1: 1078.75	valid_0's mape: 3.72934
# [400]	valid_0's l1: 1084.51	valid_0's mape: 3.74135
# [500]	valid_0's l1: 1085.74	valid_0's mape: 3.74295
# Early stopping, best iteration is:
# [300]	valid_0's l1: 1078.75	valid_0's mape: 3.72934
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1149.09	valid_0's mape: 3.99546
# [200]	valid_0's l1: 1099.78	valid_0's mape: 3.8315
# [300]	valid_0's l1: 1094.88	valid_0's mape: 3.80982
# [400]	valid_0's l1: 1097.05	valid_0's mape: 3.81439
# [500]	valid_0's l1: 1089.08	valid_0's mape: 3.78678
# [600]	valid_0's l1: 1084.56	valid_0's mape: 3.77015
# [700]	valid_0's l1: 1082.43	valid_0's mape: 3.76114
# [800]	valid_0's l1: 1077.58	valid_0's mape: 3.74258
# [900]	valid_0's l1: 1076.32	valid_0's mape: 3.7376
# [1000]	valid_0's l1: 1074.65	valid_0's mape: 3.72772
# [1100]	valid_0's l1: 1076.75	valid_0's mape: 3.7346
# Early stopping, best iteration is:
# [921]	valid_0's l1: 1073.95	valid_0's mape: 3.72834
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1163.89	valid_0's mape: 4.03208
# [200]	valid_0's l1: 1166.13	valid_0's mape: 4.02112
# [300]	valid_0's l1: 1159.71	valid_0's mape: 3.99133
# Early stopping, best iteration is:
# [148]	valid_0's l1: 1152.93	valid_0's mape: 3.99008
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1176.22	valid_0's mape: 4.07943
# [200]	valid_0's l1: 1135.73	valid_0's mape: 3.93675
# [300]	valid_0's l1: 1132.01	valid_0's mape: 3.91163
# [400]	valid_0's l1: 1132.67	valid_0's mape: 3.90625
# [500]	valid_0's l1: 1130.12	valid_0's mape: 3.89793
# [600]	valid_0's l1: 1132.02	valid_0's mape: 3.90135
# [700]	valid_0's l1: 1127.91	valid_0's mape: 3.88871
# [800]	valid_0's l1: 1128.54	valid_0's mape: 3.89017
# [900]	valid_0's l1: 1128.29	valid_0's mape: 3.88921
# [1000]	valid_0's l1: 1128.19	valid_0's mape: 3.88781
# [1100]	valid_0's l1: 1126.71	valid_0's mape: 3.88239
# [1200]	valid_0's l1: 1125.64	valid_0's mape: 3.87746
# [1300]	valid_0's l1: 1125.85	valid_0's mape: 3.87732
# [1400]	valid_0's l1: 1124.71	valid_0's mape: 3.87248
# [1500]	valid_0's l1: 1119.49	valid_0's mape: 3.85395
# [1600]	valid_0's l1: 1120.44	valid_0's mape: 3.85705
# [1700]	valid_0's l1: 1119.96	valid_0's mape: 3.85394
# Early stopping, best iteration is:
# [1469]	valid_0's l1: 1118.56	valid_0's mape: 3.85111
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1154.27	valid_0's mape: 4.02415
# [200]	valid_0's l1: 1139.32	valid_0's mape: 3.95656
# [300]	valid_0's l1: 1133.64	valid_0's mape: 3.93159
# [400]	valid_0's l1: 1125.94	valid_0's mape: 3.90081
# [500]	valid_0's l1: 1117.19	valid_0's mape: 3.86871
# [600]	valid_0's l1: 1116.37	valid_0's mape: 3.86016
# [700]	valid_0's l1: 1115.18	valid_0's mape: 3.85344
# [800]	valid_0's l1: 1101.61	valid_0's mape: 3.81069
# [900]	valid_0's l1: 1101.18	valid_0's mape: 3.80724
# [1000]	valid_0's l1: 1101.25	valid_0's mape: 3.80579
# [1100]	valid_0's l1: 1100.84	valid_0's mape: 3.80355
# [1200]	valid_0's l1: 1096.71	valid_0's mape: 3.78989
# [1300]	valid_0's l1: 1096.14	valid_0's mape: 3.78618
# [1400]	valid_0's l1: 1097.37	valid_0's mape: 3.79149
# [1500]	valid_0's l1: 1097.27	valid_0's mape: 3.79027
# Early stopping, best iteration is:
# [1258]	valid_0's l1: 1093.73	valid_0's mape: 3.77804
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1175.47	valid_0's mape: 4.07716
# [200]	valid_0's l1: 1132.11	valid_0's mape: 3.92326
# [300]	valid_0's l1: 1121.34	valid_0's mape: 3.87581
# [400]	valid_0's l1: 1119.93	valid_0's mape: 3.86077
# [500]	valid_0's l1: 1115.71	valid_0's mape: 3.83946
# [600]	valid_0's l1: 1116.86	valid_0's mape: 3.83712
# [700]	valid_0's l1: 1113.85	valid_0's mape: 3.82354
# [800]	valid_0's l1: 1109.82	valid_0's mape: 3.80785
# [900]	valid_0's l1: 1106.6	valid_0's mape: 3.79781
# [1000]	valid_0's l1: 1103.65	valid_0's mape: 3.7865
# [1100]	valid_0's l1: 1105.67	valid_0's mape: 3.7914
# [1200]	valid_0's l1: 1107.52	valid_0's mape: 3.79776
# Early stopping, best iteration is:
# [1034]	valid_0's l1: 1102.6	valid_0's mape: 3.78224
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1192.31	valid_0's mape: 4.15805
# [200]	valid_0's l1: 1156.84	valid_0's mape: 4.01863
# [300]	valid_0's l1: 1151.46	valid_0's mape: 3.98783
# [400]	valid_0's l1: 1149.66	valid_0's mape: 3.97277
# [500]	valid_0's l1: 1150.45	valid_0's mape: 3.9725
# Early stopping, best iteration is:
# [326]	valid_0's l1: 1145.15	valid_0's mape: 3.96105
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1142.34	valid_0's mape: 3.90864
# [200]	valid_0's l1: 1105.97	valid_0's mape: 3.79384
# [300]	valid_0's l1: 1095.35	valid_0's mape: 3.75803
# [400]	valid_0's l1: 1099.98	valid_0's mape: 3.77693
# [500]	valid_0's l1: 1100.29	valid_0's mape: 3.77472
# [600]	valid_0's l1: 1104.79	valid_0's mape: 3.78906
# Early stopping, best iteration is:
# [367]	valid_0's l1: 1092.84	valid_0's mape: 3.74892
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1133.97	valid_0's mape: 3.87283
# [200]	valid_0's l1: 1093.53	valid_0's mape: 3.73257
# [300]	valid_0's l1: 1097.77	valid_0's mape: 3.74915
# [400]	valid_0's l1: 1088.44	valid_0's mape: 3.71075
# [500]	valid_0's l1: 1092.67	valid_0's mape: 3.71727
# [600]	valid_0's l1: 1093.96	valid_0's mape: 3.71952
# Early stopping, best iteration is:
# [378]	valid_0's l1: 1086.31	valid_0's mape: 3.70591
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1161.19	valid_0's mape: 3.9905
# [200]	valid_0's l1: 1119.95	valid_0's mape: 3.84766
# [300]	valid_0's l1: 1109.72	valid_0's mape: 3.80886
# [400]	valid_0's l1: 1109.98	valid_0's mape: 3.80655
# [500]	valid_0's l1: 1107.68	valid_0's mape: 3.79702
# [600]	valid_0's l1: 1103.6	valid_0's mape: 3.78323
# [700]	valid_0's l1: 1104.97	valid_0's mape: 3.78898
# [800]	valid_0's l1: 1107.98	valid_0's mape: 3.79917
# Early stopping, best iteration is:
# [611]	valid_0's l1: 1102.94	valid_0's mape: 3.78154
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1133.02	valid_0's mape: 3.89891
# [200]	valid_0's l1: 1120.4	valid_0's mape: 3.85729
# [300]	valid_0's l1: 1123.94	valid_0's mape: 3.86077
# [400]	valid_0's l1: 1122.51	valid_0's mape: 3.85264
# [500]	valid_0's l1: 1124.26	valid_0's mape: 3.8564
# Early stopping, best iteration is:
# [264]	valid_0's l1: 1114.11	valid_0's mape: 3.82717
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1169.95	valid_0's mape: 4.00928
# [200]	valid_0's l1: 1141.95	valid_0's mape: 3.91292
# [300]	valid_0's l1: 1125.76	valid_0's mape: 3.85663
# [400]	valid_0's l1: 1113.34	valid_0's mape: 3.80989
# [500]	valid_0's l1: 1115.61	valid_0's mape: 3.81583
# [600]	valid_0's l1: 1114.58	valid_0's mape: 3.81545
# Early stopping, best iteration is:
# [406]	valid_0's l1: 1112.78	valid_0's mape: 3.80803
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1084.47	valid_0's mape: 3.7067
# [200]	valid_0's l1: 1052.78	valid_0's mape: 3.59767
# [300]	valid_0's l1: 1046.22	valid_0's mape: 3.57167
# [400]	valid_0's l1: 1046.6	valid_0's mape: 3.57391
# [500]	valid_0's l1: 1048.8	valid_0's mape: 3.57869
# Early stopping, best iteration is:
# [290]	valid_0's l1: 1041.76	valid_0's mape: 3.55688
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1021.61	valid_0's mape: 3.50099
# [200]	valid_0's l1: 1015.27	valid_0's mape: 3.46876
# [300]	valid_0's l1: 1015.95	valid_0's mape: 3.47048
# [400]	valid_0's l1: 1018.29	valid_0's mape: 3.47425
# Early stopping, best iteration is:
# [230]	valid_0's l1: 1009.33	valid_0's mape: 3.44839
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1057.51	valid_0's mape: 3.62571
# [200]	valid_0's l1: 1056.44	valid_0's mape: 3.61961
# [300]	valid_0's l1: 1064.78	valid_0's mape: 3.64573
# [400]	valid_0's l1: 1063.95	valid_0's mape: 3.6415
# Early stopping, best iteration is:
# [242]	valid_0's l1: 1053.42	valid_0's mape: 3.60664
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1073.91	valid_0's mape: 3.68299
# [200]	valid_0's l1: 1062.89	valid_0's mape: 3.6418
# [300]	valid_0's l1: 1061.18	valid_0's mape: 3.63854
# Early stopping, best iteration is:
# [140]	valid_0's l1: 1055.88	valid_0's mape: 3.62214
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1085.57	valid_0's mape: 3.72134
# [200]	valid_0's l1: 1078.13	valid_0's mape: 3.69455
# [300]	valid_0's l1: 1080.15	valid_0's mape: 3.7039
# [400]	valid_0's l1: 1090.9	valid_0's mape: 3.74412
# Early stopping, best iteration is:
# [173]	valid_0's l1: 1073.02	valid_0's mape: 3.67058
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1186.49	valid_0's mape: 4.19988
# [200]	valid_0's l1: 1179.78	valid_0's mape: 4.17717
# [300]	valid_0's l1: 1185.69	valid_0's mape: 4.19237
# [400]	valid_0's l1: 1181.89	valid_0's mape: 4.17598
# Early stopping, best iteration is:
# [169]	valid_0's l1: 1176.15	valid_0's mape: 4.16407
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1129.8	valid_0's mape: 4.02182
# [200]	valid_0's l1: 1107.49	valid_0's mape: 3.93536
# [300]	valid_0's l1: 1122.46	valid_0's mape: 3.98394
# [400]	valid_0's l1: 1116.85	valid_0's mape: 3.96097
# Early stopping, best iteration is:
# [197]	valid_0's l1: 1107.45	valid_0's mape: 3.935
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1171.3	valid_0's mape: 4.16515
# [200]	valid_0's l1: 1152.21	valid_0's mape: 4.09148
# [300]	valid_0's l1: 1149.67	valid_0's mape: 4.08003
# [400]	valid_0's l1: 1143.26	valid_0's mape: 4.05329
# [500]	valid_0's l1: 1140.65	valid_0's mape: 4.04443
# [600]	valid_0's l1: 1129	valid_0's mape: 4.00142
# [700]	valid_0's l1: 1127.46	valid_0's mape: 3.99517
# [800]	valid_0's l1: 1131.04	valid_0's mape: 4.00949
# [900]	valid_0's l1: 1136.29	valid_0's mape: 4.02712
# [1000]	valid_0's l1: 1136.5	valid_0's mape: 4.02805
# Early stopping, best iteration is:
# [761]	valid_0's l1: 1125.85	valid_0's mape: 3.98939
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1127.81	valid_0's mape: 3.98364
# [200]	valid_0's l1: 1116.3	valid_0's mape: 3.93263
# [300]	valid_0's l1: 1110.4	valid_0's mape: 3.91087
# [400]	valid_0's l1: 1115.26	valid_0's mape: 3.92552
# Early stopping, best iteration is:
# [163]	valid_0's l1: 1106.02	valid_0's mape: 3.89442
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1129.33	valid_0's mape: 4.00684
# [200]	valid_0's l1: 1156.09	valid_0's mape: 4.09189
# [300]	valid_0's l1: 1152.64	valid_0's mape: 4.08151
# Early stopping, best iteration is:
# [103]	valid_0's l1: 1128.78	valid_0's mape: 4.00439
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 747.144	valid_0's mape: 2.68408
# [200]	valid_0's l1: 719.138	valid_0's mape: 2.58149
# [300]	valid_0's l1: 709.917	valid_0's mape: 2.54273
# [400]	valid_0's l1: 708.22	valid_0's mape: 2.53495
# [500]	valid_0's l1: 704.394	valid_0's mape: 2.52017
# [600]	valid_0's l1: 700.742	valid_0's mape: 2.50731
# [700]	valid_0's l1: 699.347	valid_0's mape: 2.50127
# [800]	valid_0's l1: 698.499	valid_0's mape: 2.49699
# [900]	valid_0's l1: 693.692	valid_0's mape: 2.47931
# [1000]	valid_0's l1: 694.573	valid_0's mape: 2.48118
# [1100]	valid_0's l1: 692.866	valid_0's mape: 2.47458
# [1200]	valid_0's l1: 691.681	valid_0's mape: 2.46951
# [1300]	valid_0's l1: 691.763	valid_0's mape: 2.46988
# [1400]	valid_0's l1: 692.61	valid_0's mape: 2.4721
# Early stopping, best iteration is:
# [1241]	valid_0's l1: 690.863	valid_0's mape: 2.46655
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 769.368	valid_0's mape: 2.74162
# [200]	valid_0's l1: 728.516	valid_0's mape: 2.5906
# [300]	valid_0's l1: 711.081	valid_0's mape: 2.52668
# [400]	valid_0's l1: 704.756	valid_0's mape: 2.50292
# [500]	valid_0's l1: 699.407	valid_0's mape: 2.48291
# [600]	valid_0's l1: 698.224	valid_0's mape: 2.47846
# [700]	valid_0's l1: 695.487	valid_0's mape: 2.46913
# [800]	valid_0's l1: 693.888	valid_0's mape: 2.46387
# [900]	valid_0's l1: 694.368	valid_0's mape: 2.46492
# [1000]	valid_0's l1: 694.145	valid_0's mape: 2.46453
# [1100]	valid_0's l1: 692.889	valid_0's mape: 2.46042
# [1200]	valid_0's l1: 691.835	valid_0's mape: 2.45627
# [1300]	valid_0's l1: 690.944	valid_0's mape: 2.45309
# [1400]	valid_0's l1: 690.872	valid_0's mape: 2.45309
# [1500]	valid_0's l1: 689.834	valid_0's mape: 2.45011
# [1600]	valid_0's l1: 689.591	valid_0's mape: 2.44917
# [1700]	valid_0's l1: 689.646	valid_0's mape: 2.44951
# ...
# [1400]	valid_0's l1: 692.61	valid_0's mape: 2.4721
# Early stopping, best iteration is:
# [1241]	valid_0's l1: 690.863	valid_0's mape: 2.46655
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 769.368	valid_0's mape: 2.74162
# [200]	valid_0's l1: 728.516	valid_0's mape: 2.5906
# [300]	valid_0's l1: 711.081	valid_0's mape: 2.52668
# [400]	valid_0's l1: 704.756	valid_0's mape: 2.50292
# [500]	valid_0's l1: 699.407	valid_0's mape: 2.48291
# [600]	valid_0's l1: 698.224	valid_0's mape: 2.47846
# [700]	valid_0's l1: 695.487	valid_0's mape: 2.46913
# [800]	valid_0's l1: 693.888	valid_0's mape: 2.46387
# [900]	valid_0's l1: 694.368	valid_0's mape: 2.46492
# [1000]	valid_0's l1: 694.145	valid_0's mape: 2.46453
# [1100]	valid_0's l1: 692.889	valid_0's mape: 2.46042
# [1200]	valid_0's l1: 691.835	valid_0's mape: 2.45627
# [1300]	valid_0's l1: 690.944	valid_0's mape: 2.45309
# [1400]	valid_0's l1: 690.872	valid_0's mape: 2.45309
# [1500]	valid_0's l1: 689.834	valid_0's mape: 2.45011
# [1600]	valid_0's l1: 689.591	valid_0's mape: 2.44917
# [1700]	valid_0's l1: 689.646	valid_0's mape: 2.44951
# [1800]	valid_0's l1: 689.551	valid_0's mape: 2.44889
# [1900]	valid_0's l1: 688.679	valid_0's mape: 2.44571
# [2000]	valid_0's l1: 687.289	valid_0's mape: 2.43968
# [2100]	valid_0's l1: 687.213	valid_0's mape: 2.43928
# [2200]	valid_0's l1: 685.958	valid_0's mape: 2.43375
# [2300]	valid_0's l1: 684.809	valid_0's mape: 2.42983
# [2400]	valid_0's l1: 685.882	valid_0's mape: 2.43382
# [2500]	valid_0's l1: 684.691	valid_0's mape: 2.42886
# [2600]	valid_0's l1: 684.891	valid_0's mape: 2.4293
# Early stopping, best iteration is:
# [2431]	valid_0's l1: 684.285	valid_0's mape: 2.42697
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 758.021	valid_0's mape: 2.70334
# [200]	valid_0's l1: 723.598	valid_0's mape: 2.58127
# [300]	valid_0's l1: 717.259	valid_0's mape: 2.55776
# [400]	valid_0's l1: 713.912	valid_0's mape: 2.54546
# [500]	valid_0's l1: 708.908	valid_0's mape: 2.53001
# [600]	valid_0's l1: 707.52	valid_0's mape: 2.52582
# [700]	valid_0's l1: 703.663	valid_0's mape: 2.51205
# [800]	valid_0's l1: 699.939	valid_0's mape: 2.49934
# [900]	valid_0's l1: 697.76	valid_0's mape: 2.49173
# [1000]	valid_0's l1: 697.094	valid_0's mape: 2.48983
# [1100]	valid_0's l1: 698.004	valid_0's mape: 2.49303
# [1200]	valid_0's l1: 697.999	valid_0's mape: 2.49238
# [1300]	valid_0's l1: 698.249	valid_0's mape: 2.49379
# Early stopping, best iteration is:
# [1071]	valid_0's l1: 696.419	valid_0's mape: 2.48742
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 786.808	valid_0's mape: 2.7971
# [200]	valid_0's l1: 734.655	valid_0's mape: 2.61481
# [300]	valid_0's l1: 719.143	valid_0's mape: 2.56143
# [400]	valid_0's l1: 713.184	valid_0's mape: 2.54168
# [500]	valid_0's l1: 708.798	valid_0's mape: 2.52623
# [600]	valid_0's l1: 710.627	valid_0's mape: 2.53311
# [700]	valid_0's l1: 708.371	valid_0's mape: 2.52337
# [800]	valid_0's l1: 703.134	valid_0's mape: 2.50412
# [900]	valid_0's l1: 703.457	valid_0's mape: 2.50575
# [1000]	valid_0's l1: 702.931	valid_0's mape: 2.50349
# Early stopping, best iteration is:
# [818]	valid_0's l1: 702.352	valid_0's mape: 2.50191
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 763.929	valid_0's mape: 2.72602
# [200]	valid_0's l1: 733.191	valid_0's mape: 2.61951
# [300]	valid_0's l1: 718.371	valid_0's mape: 2.56289
# [400]	valid_0's l1: 714.431	valid_0's mape: 2.55041
# [500]	valid_0's l1: 708.102	valid_0's mape: 2.52829
# [600]	valid_0's l1: 703.282	valid_0's mape: 2.51003
# [700]	valid_0's l1: 698.924	valid_0's mape: 2.49059
# [800]	valid_0's l1: 696.962	valid_0's mape: 2.48316
# [900]	valid_0's l1: 696.889	valid_0's mape: 2.482
# [1000]	valid_0's l1: 695.795	valid_0's mape: 2.47666
# [1100]	valid_0's l1: 693.902	valid_0's mape: 2.46979
# [1200]	valid_0's l1: 691.013	valid_0's mape: 2.45841
# [1300]	valid_0's l1: 691.195	valid_0's mape: 2.45936
# [1400]	valid_0's l1: 692.151	valid_0's mape: 2.46351
# Early stopping, best iteration is:
# [1239]	valid_0's l1: 690.248	valid_0's mape: 2.45598
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 871.12	valid_0's mape: 3.10911
# [200]	valid_0's l1: 824.72	valid_0's mape: 2.93256
# [300]	valid_0's l1: 814.963	valid_0's mape: 2.89813
# [400]	valid_0's l1: 808.671	valid_0's mape: 2.87279
# [500]	valid_0's l1: 805.158	valid_0's mape: 2.86102
# [600]	valid_0's l1: 800.489	valid_0's mape: 2.8457
# [700]	valid_0's l1: 796.747	valid_0's mape: 2.83199
# [800]	valid_0's l1: 795.33	valid_0's mape: 2.8278
# [900]	valid_0's l1: 793.76	valid_0's mape: 2.82308
# [1000]	valid_0's l1: 793.165	valid_0's mape: 2.81985
# [1100]	valid_0's l1: 792.883	valid_0's mape: 2.81892
# [1200]	valid_0's l1: 792.095	valid_0's mape: 2.81551
# [1300]	valid_0's l1: 791.572	valid_0's mape: 2.81624
# [1400]	valid_0's l1: 790.616	valid_0's mape: 2.81195
# [1500]	valid_0's l1: 790.645	valid_0's mape: 2.81203
# [1600]	valid_0's l1: 790.752	valid_0's mape: 2.81268
# [1700]	valid_0's l1: 789.69	valid_0's mape: 2.80939
# [1800]	valid_0's l1: 789.659	valid_0's mape: 2.80915
# [1900]	valid_0's l1: 790.363	valid_0's mape: 2.81156
# Early stopping, best iteration is:
# [1716]	valid_0's l1: 789.272	valid_0's mape: 2.80785
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 849.747	valid_0's mape: 3.03018
# [200]	valid_0's l1: 809.165	valid_0's mape: 2.87872
# [300]	valid_0's l1: 802.651	valid_0's mape: 2.85063
# [400]	valid_0's l1: 793.58	valid_0's mape: 2.81833
# [500]	valid_0's l1: 792.889	valid_0's mape: 2.81744
# [600]	valid_0's l1: 790.832	valid_0's mape: 2.80887
# [700]	valid_0's l1: 789.27	valid_0's mape: 2.80354
# [800]	valid_0's l1: 789.089	valid_0's mape: 2.80276
# [900]	valid_0's l1: 789.96	valid_0's mape: 2.80678
# [1000]	valid_0's l1: 788.449	valid_0's mape: 2.80117
# [1100]	valid_0's l1: 788.153	valid_0's mape: 2.79975
# [1200]	valid_0's l1: 786.456	valid_0's mape: 2.79304
# [1300]	valid_0's l1: 783.954	valid_0's mape: 2.78424
# [1400]	valid_0's l1: 782.372	valid_0's mape: 2.77811
# [1500]	valid_0's l1: 781.569	valid_0's mape: 2.77545
# [1600]	valid_0's l1: 781.716	valid_0's mape: 2.77559
# [1700]	valid_0's l1: 782.231	valid_0's mape: 2.77655
# [1800]	valid_0's l1: 783.743	valid_0's mape: 2.78205
# Early stopping, best iteration is:
# [1628]	valid_0's l1: 780.953	valid_0's mape: 2.77265
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 840.046	valid_0's mape: 2.99782
# [200]	valid_0's l1: 816.783	valid_0's mape: 2.90805
# [300]	valid_0's l1: 816.42	valid_0's mape: 2.9074
# [400]	valid_0's l1: 811.882	valid_0's mape: 2.89195
# [500]	valid_0's l1: 806.969	valid_0's mape: 2.87469
# [600]	valid_0's l1: 805.182	valid_0's mape: 2.86813
# [700]	valid_0's l1: 804.253	valid_0's mape: 2.86612
# [800]	valid_0's l1: 802.229	valid_0's mape: 2.85927
# [900]	valid_0's l1: 803.053	valid_0's mape: 2.86189
# [1000]	valid_0's l1: 801.319	valid_0's mape: 2.85384
# [1100]	valid_0's l1: 802.363	valid_0's mape: 2.85814
# [1200]	valid_0's l1: 801.519	valid_0's mape: 2.85476
# Early stopping, best iteration is:
# [1017]	valid_0's l1: 800.768	valid_0's mape: 2.85166
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 867.798	valid_0's mape: 3.08983
# [200]	valid_0's l1: 834.263	valid_0's mape: 2.9647
# [300]	valid_0's l1: 825.71	valid_0's mape: 2.93488
# [400]	valid_0's l1: 817.86	valid_0's mape: 2.90701
# [500]	valid_0's l1: 819.332	valid_0's mape: 2.91096
# [600]	valid_0's l1: 816.689	valid_0's mape: 2.90041
# [700]	valid_0's l1: 814.004	valid_0's mape: 2.89278
# [800]	valid_0's l1: 814.897	valid_0's mape: 2.89698
# [900]	valid_0's l1: 812.976	valid_0's mape: 2.88823
# Early stopping, best iteration is:
# [652]	valid_0's l1: 811.615	valid_0's mape: 2.88402
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 856.641	valid_0's mape: 3.0413
# [200]	valid_0's l1: 842.37	valid_0's mape: 2.9844
# [300]	valid_0's l1: 839.379	valid_0's mape: 2.96928
# [400]	valid_0's l1: 836.877	valid_0's mape: 2.96447
# [500]	valid_0's l1: 838.589	valid_0's mape: 2.97177
# Early stopping, best iteration is:
# [323]	valid_0's l1: 834.621	valid_0's mape: 2.95551
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 774.263	valid_0's mape: 2.71554
# [200]	valid_0's l1: 733.366	valid_0's mape: 2.57197
# [300]	valid_0's l1: 729.823	valid_0's mape: 2.55538
# [400]	valid_0's l1: 725.144	valid_0's mape: 2.53606
# [500]	valid_0's l1: 725.602	valid_0's mape: 2.53755
# [600]	valid_0's l1: 722.274	valid_0's mape: 2.52575
# [700]	valid_0's l1: 723.488	valid_0's mape: 2.52959
# Early stopping, best iteration is:
# [451]	valid_0's l1: 721.048	valid_0's mape: 2.52126
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 764.671	valid_0's mape: 2.67012
# [200]	valid_0's l1: 742.69	valid_0's mape: 2.59089
# [300]	valid_0's l1: 733.225	valid_0's mape: 2.55861
# [400]	valid_0's l1: 729.835	valid_0's mape: 2.54735
# [500]	valid_0's l1: 726.776	valid_0's mape: 2.53545
# [600]	valid_0's l1: 724.232	valid_0's mape: 2.52579
# [700]	valid_0's l1: 725.599	valid_0's mape: 2.53153
# [800]	valid_0's l1: 726.925	valid_0's mape: 2.53706
# Early stopping, best iteration is:
# [610]	valid_0's l1: 723.424	valid_0's mape: 2.52349
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 781.243	valid_0's mape: 2.73535
# [200]	valid_0's l1: 759.318	valid_0's mape: 2.66638
# [300]	valid_0's l1: 753.36	valid_0's mape: 2.6439
# [400]	valid_0's l1: 745.276	valid_0's mape: 2.61928
# [500]	valid_0's l1: 747.403	valid_0's mape: 2.63288
# [600]	valid_0's l1: 747.804	valid_0's mape: 2.63276
# Early stopping, best iteration is:
# [438]	valid_0's l1: 740.004	valid_0's mape: 2.6054
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 778.494	valid_0's mape: 2.722
# [200]	valid_0's l1: 756.146	valid_0's mape: 2.64178
# [300]	valid_0's l1: 749.028	valid_0's mape: 2.61888
# [400]	valid_0's l1: 745.501	valid_0's mape: 2.6059
# [500]	valid_0's l1: 743.348	valid_0's mape: 2.59812
# [600]	valid_0's l1: 744.077	valid_0's mape: 2.6005
# [700]	valid_0's l1: 742.997	valid_0's mape: 2.5973
# [800]	valid_0's l1: 741.835	valid_0's mape: 2.59335
# [900]	valid_0's l1: 741.144	valid_0's mape: 2.59041
# [1000]	valid_0's l1: 736.692	valid_0's mape: 2.57964
# [1100]	valid_0's l1: 736.736	valid_0's mape: 2.58006
# [1200]	valid_0's l1: 735.959	valid_0's mape: 2.57723
# [1300]	valid_0's l1: 737.518	valid_0's mape: 2.58132
# [1400]	valid_0's l1: 737.258	valid_0's mape: 2.58002
# Early stopping, best iteration is:
# [1182]	valid_0's l1: 735.37	valid_0's mape: 2.57549
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 796.402	valid_0's mape: 2.78623
# [200]	valid_0's l1: 765.509	valid_0's mape: 2.67807
# [300]	valid_0's l1: 761.987	valid_0's mape: 2.65818
# [400]	valid_0's l1: 755.499	valid_0's mape: 2.63564
# [500]	valid_0's l1: 753.988	valid_0's mape: 2.63032
# [600]	valid_0's l1: 755.38	valid_0's mape: 2.63334
# [700]	valid_0's l1: 756.968	valid_0's mape: 2.63763
# [800]	valid_0's l1: 753.256	valid_0's mape: 2.62362
# Early stopping, best iteration is:
# [558]	valid_0's l1: 751.351	valid_0's mape: 2.62092
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 788.401	valid_0's mape: 2.75847
# [200]	valid_0's l1: 781.154	valid_0's mape: 2.72481
# [300]	valid_0's l1: 767.363	valid_0's mape: 2.67278
# [400]	valid_0's l1: 764.533	valid_0's mape: 2.65912
# [500]	valid_0's l1: 763.205	valid_0's mape: 2.65323
# [600]	valid_0's l1: 762.825	valid_0's mape: 2.64925
# [700]	valid_0's l1: 761.784	valid_0's mape: 2.64108
# [800]	valid_0's l1: 761.154	valid_0's mape: 2.63719
# [900]	valid_0's l1: 760.201	valid_0's mape: 2.63449
# [1000]	valid_0's l1: 762.806	valid_0's mape: 2.64278
# Early stopping, best iteration is:
# [778]	valid_0's l1: 758.304	valid_0's mape: 2.62674
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 743.745	valid_0's mape: 2.58179
# [200]	valid_0's l1: 723.547	valid_0's mape: 2.50903
# [300]	valid_0's l1: 718.976	valid_0's mape: 2.4936
# [400]	valid_0's l1: 711.715	valid_0's mape: 2.46699
# [500]	valid_0's l1: 714.253	valid_0's mape: 2.47436
# [600]	valid_0's l1: 715.333	valid_0's mape: 2.47767
# [700]	valid_0's l1: 716.42	valid_0's mape: 2.48121
# Early stopping, best iteration is:
# [496]	valid_0's l1: 710.558	valid_0's mape: 2.46218
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 785.844	valid_0's mape: 2.72329
# [200]	valid_0's l1: 757.607	valid_0's mape: 2.61978
# [300]	valid_0's l1: 747.017	valid_0's mape: 2.57675
# [400]	valid_0's l1: 742.257	valid_0's mape: 2.55922
# [500]	valid_0's l1: 741.621	valid_0's mape: 2.56003
# [600]	valid_0's l1: 741.96	valid_0's mape: 2.56276
# [700]	valid_0's l1: 738.881	valid_0's mape: 2.55293
# [800]	valid_0's l1: 738.132	valid_0's mape: 2.55004
# [900]	valid_0's l1: 735.073	valid_0's mape: 2.539
# [1000]	valid_0's l1: 735.881	valid_0's mape: 2.54173
# [1100]	valid_0's l1: 734.323	valid_0's mape: 2.53665
# [1200]	valid_0's l1: 737.692	valid_0's mape: 2.54863
# [1300]	valid_0's l1: 735.92	valid_0's mape: 2.54358
# Early stopping, best iteration is:
# [1111]	valid_0's l1: 734.091	valid_0's mape: 2.53589
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 781.818	valid_0's mape: 2.70985
# [200]	valid_0's l1: 770.311	valid_0's mape: 2.65812
# [300]	valid_0's l1: 768.29	valid_0's mape: 2.64528
# [400]	valid_0's l1: 760.533	valid_0's mape: 2.61669
# [500]	valid_0's l1: 757.435	valid_0's mape: 2.60401
# [600]	valid_0's l1: 758.415	valid_0's mape: 2.60671
# [700]	valid_0's l1: 759.537	valid_0's mape: 2.60894
# Early stopping, best iteration is:
# [535]	valid_0's l1: 756.824	valid_0's mape: 2.6023
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 761.316	valid_0's mape: 2.6501
# [200]	valid_0's l1: 737.528	valid_0's mape: 2.56311
# [300]	valid_0's l1: 735.41	valid_0's mape: 2.55087
# [400]	valid_0's l1: 731.519	valid_0's mape: 2.53726
# [500]	valid_0's l1: 731.364	valid_0's mape: 2.53437
# [600]	valid_0's l1: 730.871	valid_0's mape: 2.53324
# [700]	valid_0's l1: 733.372	valid_0's mape: 2.54198
# [800]	valid_0's l1: 732.907	valid_0's mape: 2.53827
# Early stopping, best iteration is:
# [558]	valid_0's l1: 729.415	valid_0's mape: 2.52839
# Seed-- 0
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 917.001	valid_0's mape: 3.28586
# [200]	valid_0's l1: 927.018	valid_0's mape: 3.31862
# [300]	valid_0's l1: 933.991	valid_0's mape: 3.34255
# Early stopping, best iteration is:
# [90]	valid_0's l1: 901.763	valid_0's mape: 3.23053
# Seed-- 1
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 894.749	valid_0's mape: 3.21685
# [200]	valid_0's l1: 901.987	valid_0's mape: 3.23776
# [300]	valid_0's l1: 928.071	valid_0's mape: 3.32525
# Early stopping, best iteration is:
# [99]	valid_0's l1: 894.056	valid_0's mape: 3.21475
# Seed-- 2
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 1029.41	valid_0's mape: 3.69765
# [200]	valid_0's l1: 1030.35	valid_0's mape: 3.68976
# [300]	valid_0's l1: 1049.89	valid_0's mape: 3.75385
# Early stopping, best iteration is:
# [54]	valid_0's l1: 969.888	valid_0's mape: 3.48247
# Seed-- 3
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 933.1	valid_0's mape: 3.36481
# [200]	valid_0's l1: 928.123	valid_0's mape: 3.34038
# [300]	valid_0's l1: 922.464	valid_0's mape: 3.31745
# [400]	valid_0's l1: 942.385	valid_0's mape: 3.39025
# [500]	valid_0's l1: 939.097	valid_0's mape: 3.37471
# Early stopping, best iteration is:
# [302]	valid_0's l1: 920.939	valid_0's mape: 3.31198
# Seed-- 4
# Training until validation scores don't improve for 250 rounds
# [100]	valid_0's l1: 932.255	valid_0's mape: 3.34101
# [200]	valid_0's l1: 980.82	valid_0's mape: 3.52102
# [300]	valid_0's l1: 989.295	valid_0's mape: 3.54821
# Early stopping, best iteration is:
# [67]	valid_0's l1: 906.85	valid_0's mape: 3.24811

# %% [markdown]
# After a long training and validation, finally we are able to see the results.

# %%
for std_dev in errors:
    y_with_noise = [i for i in test_scores[f"std_{std_dev}"][f"train_noise_True"].values()]
    y_without_noise = [i for i in test_scores[f"std_{std_dev}"][f"train_noise_False"].values()]
    y_without_weather = [i for i in test_scores_for_weather["without_weather"].values()]
    x_with_noise = np.arange(len(y_with_noise))
    x_without_noise = x_with_noise + 0.25
    x_without_weather = x_without_noise + 0.25

    fig, ax = plt.subplots(figsize=(10, 6))
    ax.bar(x_with_noise, y_with_noise, width=0.25, label='with_noise')
    ax.bar(x_without_noise, y_without_noise, width=0.25, label='without_noise')
    ax.bar(x_without_weather, y_without_weather, width=0.25, label='without_weather')
    ax.set_xticks(x_with_noise + 0.25)
    ax.set_xticklabels([f"Fold {i+1}" for i in range(len(y_with_noise))])
    ax.set_xlabel('Folds')
    ax.set_ylabel('Test scores')
    ax.set_title(f"Standard deviation: {std_dev}")
    ax.legend()
    plt.show()

# %% [markdown]
# To sum things up, at first we had a historical electricity consumption data and we extracted some basic and useful features. Then we wanted to add weather data to improve the model performance. We first directly used the weather data in seen data and saw promising result. However, weather data has a different characteristic from historical consumption data. One of it is historical but the other part, probably forecasting period, is forecast of the data source we use. This is why we must simulate the deployment phase of our forecasting model and not decide to use a forecasted features only by validating in historical data. To simulate, we added different amounts of forecasting error to test sets and compared the results when we did and did not add a similar noise signal to the train and validation tests, and we did not use any weather forecasting feature. As you can see in the last figure, if forecasting error is low model performs better than not using any weather features and adding noise to train/validation data improves even more. As forecasting error increases using weather features dramatically decreases model performance and becames the worst thing to do. And even if using weather data gets useless, adding noise to train set protects the model from being misleaded.
